# %%
import time
import numpy as np
import torch as torch
#import tf_cnnvis
import logging
import importlib
import sys
import os
import torch.nn as nn

FREQ_PRINT = 200 # print frequency image tensorboard [20]
FREQ_EV = 1
PATIENCE = 10

# %%
from utils.adapt_data import batch_fill
from utils.evaluations import save_results, heatmap
from utils.constants import IMAGES_DATASETS

from torchsummary import summary
# Out:
# /home/austrotaxus/anaconda3/envs/marsanomalies/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
learning_rate = 0.0002
batch_size = 32
latent_dim = 100

dataset = "cifar10"
label =1 
device = 'cuda'

# %%
def display_parameters(batch_size, starting_lr, ema_decay, degree, label,
                       allow_zz, score_method, do_spectral_norm):
    """See parameters
    """
    print('Batch size: ', batch_size)
    print('Starting learning rate: ', starting_lr)
    print('EMA Decay: ', ema_decay)
    print('Degree for L norms: ', degree)
    print('Anomalous label: ', label)
    print('Score method: ', score_method)
    print('Discriminator zz enabled: ', allow_zz)
    print('Spectral Norm enabled: ', do_spectral_norm)

def display_progression_epoch(j, id_max):
    """See epoch progression
    """
    batch_progression = int((j / id_max) * 100)
    sys.stdout.write(str(batch_progression) + ' % epoch' + chr(13))
    _ = sys.stdout.flush

# %%
def create_logdir(dataset, label, rd,
                  allow_zz, score_method, do_spectral_norm):
    """ Directory to save training logs, weights, biases, etc."""
    model = 'alad_sn{}_dzz{}'.format(do_spectral_norm, allow_zz)
    return "train_logs/{}/{}/dzzenabled{}/{}/label{}/" \
           "rd{}".format(dataset, model, allow_zz,
            score_method, label, rd)

# %%
"""
CIFAR10 ALAD architecture.
Generator (decoder), encoder and discriminator.
"""
import torch as torch
#from utils import sn

#init_kernel = tf.random_normal_initializer(mean=0.0, stddev=0.01)

class Encoder_Network(nn.Module):
    def __init__(self, is_training=False, getter=None, reuse=False,
            do_spectral_norm=True):
        """ Encoder architecture in tensorflow
        Maps the data into the latent space
        Args:
            x_inp (tensor): input data for the encoder.
            is_training (bool): for batch norms and dropouts
            getter: for exponential moving average during inference
            reuse (bool): sharing variables or not
        Returns:
        net (tensor): last activation layer of the encoder
        """
        super(Encoder_Network, self).__init__()
        layers = []


        layers.append(torch.nn.Conv2d(3,128,kernel_size = 4,stride = 2, padding = 1))
        layers.append(torch.nn.BatchNorm2d(128))
        layers.append(torch.nn.LeakyReLU(negative_slope=0.2))

        layers.append(torch.nn.Conv2d(128,256,kernel_size = 4,stride = 2, padding = 1))
        layers.append(torch.nn.BatchNorm2d(256))
        layers.append(torch.nn.LeakyReLU(negative_slope=0.2))

        layers.append(torch.nn.Conv2d(256,512,kernel_size = 4,stride = 2, padding = 1))
        layers.append(torch.nn.BatchNorm2d(512))
        layers.append(torch.nn.LeakyReLU(negative_slope=0.2))

        
        layers.append(torch.nn.Conv2d(512,latent_dim,kernel_size =4,stride = 1, padding = 0))
        #layers.append(torch.nn.BatchNorm2d(batch_size)
        #layers.append(torch.nn.LeakyRelu(negative_slope=0.2))    
        self.enc = nn.Sequential(*layers).to(device)
    
    def forward(self,x):
        return self.enc(x.to(device))


class Decoder_Network(nn.Module):
    def __init__(self,is_training=False, getter=None, reuse=False,
            do_spectral_norm=True):
        
        norm = lambda x : nn.utils.spectral_norm(x) if do_spectral_norm else lambda x: x
        super(Decoder_Network, self).__init__()
                      
        layers = []

            
 #       x_inp = x_inp.view(-1, 32, 32, 3)

        layers.append(norm(
            nn.ConvTranspose2d(latent_dim,512,kernel_size = 4,stride = 1, padding = 0)
            ))
    
        layers.append(torch.nn.BatchNorm2d(512))
        layers.append(nn.ReLU())

        layers.append(norm(nn.ConvTranspose2d(512,256,kernel_size =  4,stride = 2, padding = 1)))
        layers.append(torch.nn.BatchNorm2d(256))
        layers.append(nn.ReLU())

        layers.append(norm(nn.ConvTranspose2d(256,128,kernel_size = 4,stride = 2, padding = 1)))
        layers.append(torch.nn.BatchNorm2d(128))
        layers.append(nn.ReLU())

        layers.append(norm(nn.ConvTranspose2d(128,3,kernel_size = 4,stride = 2, padding = 1)))
        layers.append(torch.nn.Tanh())
        #layers.append(torch.nn.LeakyRelu(negative_slope=0.2))    
        self.enc = nn.Sequential(*layers).to(device)                     
        print(self)
    
    def forward(self, z):
        z = z.view(-1,latent_dim,1,1)
        return self.enc(z.to(device))

# %%
class Data_Network_xz(nn.Module):
    def __init__(self,is_training=False, getter=None, reuse=False,
        do_spectral_norm=True):
        super(Data_Network_xz, self).__init__()
        x_layers = []
        z_layers = []
        norm = lambda x : nn.utils.spectral_norm(x) if do_spectral_norm else lambda x: x
        
        x_layers.append(norm(nn.Conv2d(3,128,kernel_size = 4, stride = 2, padding = 1)))
        x_layers.append(nn.BatchNorm2d(128))
        x_layers.append(nn.LeakyReLU(0.2))
                        
        x_layers.append(norm(nn.Conv2d(128,256,kernel_size = 4, stride = 2, padding = 1)))
        x_layers.append(nn.BatchNorm2d(256))
        x_layers.append(nn.LeakyReLU(0.2))
        
        x_layers.append(norm(nn.Conv2d(256,512,kernel_size = 4, stride = 2, padding = 1)))
        x_layers.append(nn.BatchNorm2d(512))
        x_layers.append(nn.LeakyReLU(0.2))
                                                
        z_layers.append(norm(nn.Conv2d(latent_dim,512,kernel_size=1, stride = 1)))
        z_layers.append(nn.LeakyReLU(0.2))
        z_layers.append(nn.Dropout2d(p=0.2))
                        
        z_layers.append(norm(nn.Conv2d(512,512,kernel_size=1, stride = 1)))
        z_layers.append(nn.LeakyReLU(0.2))
        z_layers.append(nn.Dropout2d(p=0.2))
                        
        self.x_net =nn.Sequential(*x_layers).to(device)                     
        self.z_net = nn.Sequential(*z_layers).to(device)                     
       
        y_layers = []
        
        y_layers.append(norm(nn.Conv2d((512*17),1024,kernel_size = 1)))
        y_layers.append(nn.LeakyReLU(0.2))
        y_layers.append(nn.Dropout2d(p=0.2))
                
        self.intermediate_net = nn.Sequential(*y_layers).to(device) 
                        
        y_layers.append(norm(nn.Conv2d(1024,1,kernel_size = 1)))
        y_layers.append(nn.LeakyReLU(0.2))
        y_layers.append(nn.Dropout2d(p=0.2))
            
        self.y_net = nn.Sequential(*y_layers).to(device) 
    
    def forward(self, x , z):
        
        x_i = self.x_net(x.to(device))
        z_i = z.view([-1, latent_dim, 1, 1])
        z_i = self.z_net(z_i.to(device))
        
        x_i = x_i.view([-1,512*4*4,1,1])
        
        y = torch.cat((x_i,z_i),1)
        res1,res2 = self.y_net(y), self.intermediate_net(y)
        del y, x_i, z_i
        # Strange behaviour of garbage collector!
        return res1,res2
     
                        
class Data_Network_xx(nn.Module):
    def __init__(self,is_training=False, getter=None, reuse=False, do_spectral_norm=True):
        super(Data_Network_xx, self).__init__()
        norm = lambda x : nn.utils.spectral_norm(x) if do_spectral_norm else lambda x: x
        layers = []
        layers.append(norm(nn.Conv2d(6,64,kernel_size = 5, stride = 2, padding = 2)))
        layers.append(nn.LeakyReLU(0.2))
        layers.append(nn.Dropout2d(p=0.2))
        layers.append(norm(nn.Conv2d(64,128,kernel_size = 5, padding = 2,stride = 2)))
        layers.append(nn.LeakyReLU(0.2))
        layers.append(nn.Dropout2d(p=0.2))
        self.net = nn.Sequential(*layers).to(device) 
        self.dense = norm(nn.Linear(128*8*8,1)).to(device)
        
    def forward(self, x , x_rec):             
        y = torch.cat((x.to(device),x_rec.to(device)),1)
        intermediate_layer = self.net(y).view(-1,128*8*8)
        logits = self.dense(intermediate_layer)
        del y
        return logits, intermediate_layer

class Data_Network_zz(nn.Module):
    def __init__(self,is_training=False, getter=None, reuse=False, do_spectral_norm=True):
        super(Data_Network_zz, self).__init__()
        norm = lambda x : nn.utils.spectral_norm(x) if do_spectral_norm else lambda x: x
        layers = []
        layers.append(norm(nn.Linear(100*2,64)))
        layers.append(nn.LeakyReLU(0.2))
        layers.append(nn.Dropout2d(p=0.2))
        layers.append(norm(nn.Linear(64,32)))
        layers.append(nn.LeakyReLU(0.2))
        layers.append(nn.Dropout2d(p=0.2))
        self.net = nn.Sequential(*layers).to(device)
        
        self.dense = norm(nn.Linear(32,1)).to(device)
        
    def forward(self, z , z_rec):
        z = z.view([-1, latent_dim])
        z_rec = z_rec.view([-1,latent_dim])
        y = torch.cat((z.to(device),z_rec.to(device)),1)
        intermediate_layer = self.net(y).view(-1,32)
        logits = self.dense(intermediate_layer)
        del z, z_rec,y
        
        return logits, intermediate_layer

# %%
dn_zz = Data_Network_zz()
dn_xx = Data_Network_xx()
dn_xz = Data_Network_xz()

gen = Decoder_Network()
inf = Encoder_Network()
# Out:
# /home/austrotaxus/anaconda3/envs/marsanomalies/lib/python3.6/site-packages/torch/cuda/__init__.py:116: UserWarning:
#     Found GPU0 GeForce GTX 660 which is of cuda capability 3.0.
#     PyTorch no longer supports this GPU because it is too old.
#
#   warnings.warn(old_gpu_warn % (d, name, major, capability[1]))
# Decoder_Network(
#   (enc): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (10): Tanh()
#   )
# )

# %%
import logging
import pickle
import math
import os
import errno
import tarfile
import shutil
import numpy as np
import urllib3
from sklearn.model_selection import train_test_split
from utils.adapt_data import adapt_labels_outlier_task

logger = logging.getLogger(__name__)

def get_train(label=-1, centered=True, normalize=True):
    return _get_adapted_dataset("train", label, centered, normalize)

def get_test(label=-1, centered=True, normalize=True):
    return _get_adapted_dataset("test", label, centered, normalize)

def get_valid(label=-1, centered=True, normalize=True):
    return _get_adapted_dataset("valid", label, centered, normalize)
    
def get_shape_input():
    return (None, 32, 32, 3)

def get_shape_input_flatten():
    return (None, 32*32*3)

def get_shape_label():
    return (None,)

def num_classes():
    return 10

def get_anomalous_proportion():
    return 0.9

def _unpickle_file(filename):
    logger.debug("Loading pickle file: {}".format(filename))

    with open(filename, mode='rb') as file:
        data = pickle.load(file, encoding='bytes')

    # Reorder the data
    img = data[b'data']
    img = img.reshape([-1, 3, 32, 32])
    
    # I need channels first
    #img = img.transpose([0, 2, 3, 1])
    
    # Load labels
    lbl = np.array(data[b'labels'])

    return img, lbl

def _get_dataset(split, centered=False, normalize=False):
    '''
    Gets the adapted dataset for the experiments
    Args : 
            split (str): train or test
            normalize (bool): (Default=True) normalize data
            centered (bool): (Default=False) data centered to [-1, 1]
    Returns : 
            (tuple): <training, testing> images and labels
    '''
    path = "data"
    dirname = "cifar-10-batches-py"
    data_url = "http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"

    if not os.path.exists(os.path.join(path, dirname)):
        # Extract or download data
        try:
            os.makedirs(path)
        except OSError as exception:
            if exception.errno != errno.EEXIST:
                raise
        
        file_path = os.path.join(path, data_url.split('/')[-1])
        if not os.path.exists(file_path):
            # Download
            logger.warn("Downloading {}".format(data_url))
            with urllib3.PoolManager().request('GET', data_url, preload_content=False) as r, \
                 open(file_path, 'wb') as w:
                    shutil.copyfileobj(r, w)

        logger.warn("Unpacking {}".format(file_path))
        # Unpack data
        tarfile.open(name=file_path, mode="r:gz").extractall(path)

    # Import the data
    if split == 'test':
        filenames = ["test_batch"] 
    # elif split == 'valid':
    #     filenames = ["data_batch_5"]
    else:
        filenames = ["data_batch_{}".format(i) for i in range(1, 6)]
    
    imgs = []
    lbls = []
    for f in filenames:
        img, lbl = _unpickle_file(os.path.join(path, dirname, f))
        imgs.append(img)
        lbls.append(lbl)

    # Now we flatten the arrays
    imgs = np.concatenate(imgs)
    lbls = np.concatenate(lbls)

    # Convert images to [0..1] range
    if normalize:
        imgs = imgs.astype(np.float32)/255.0
    if centered:
        imgs = imgs.astype(np.float32)*2. - 1.
    return imgs.astype(np.float32), lbls

def _get_adapted_dataset(split, label=None, centered=False, normalize=False):
    """
    Gets the adapted dataset for the experiments
    Args : 
            split (str): train or test
            mode (str): inlier or outlier
            label (int): int in range 0 to 10, is the class/digit
                         which is considered inlier or outlier
            rho (float): proportion of anomalous classes INLIER
                         MODE ONLY
            centered (bool): (Default=False) data centered to [-1, 1]
    Returns : 
            (tuple): <training, testing> images and labels
    """
    dataset = {}
    dataset['x_train'],  dataset['y_train'] = _get_dataset('train',
                                                           centered=centered,
                                                           normalize=normalize)
    dataset['x_test'], dataset['y_test'] = _get_dataset('test', centered=centered,
                                                           normalize=normalize)

    full_x_data = np.concatenate([dataset['x_train'], dataset['x_test']], axis=0)
    full_y_data = np.concatenate([dataset['y_train'], dataset['y_test']], axis=0)
    
    full_y_data[full_y_data == 10] = 0

    dataset['x_train'], dataset['x_test'], \
    dataset['y_train'], dataset['y_test'] = train_test_split(full_x_data,
                                                             full_y_data,
                                                             test_size=0.2,
                                                             random_state=42)
    
    dataset['x_train'], dataset['x_valid'], \
    dataset['y_train'], dataset['y_valid'] = train_test_split(dataset['x_train'],
                                                             dataset['y_train'],
                                                             test_size=0.25,
                                                             random_state=42)


    key_img = 'x_' + split
    key_lbl = 'y_' + split

    if label != -1:

        if split in ['train', 'valid']:

            inliers = dataset[key_img][dataset[key_lbl] == label], \
                      dataset[key_lbl][dataset[key_lbl] == label]
            outliers = dataset[key_img][dataset[key_lbl] != label], \
                       dataset[key_lbl][dataset[key_lbl] != label]

            dataset[key_img], dataset[key_lbl] = inliers

            dataset[key_lbl] = adapt_labels_outlier_task(dataset[key_lbl],
                                                         label)
            return (dataset[key_img], dataset[key_lbl])
        else:
            dataset[key_lbl] = adapt_labels_outlier_task(dataset[key_lbl],
                                                         label)

            return (dataset[key_img], dataset[key_lbl])

# %%
random_seed = 42
rng = np.random.RandomState(random_seed)

trainx, trainy =  _get_dataset("train")
testx, testy = _get_dataset("test")
nr_batches_train = int(trainx.shape[0] / batch_size)
nr_batches_test = int(testx.shape[0] / batch_size)

# %%
import subprocess

def get_gpu_memory_map():
    """Get the current gpu usage.

    Returns
    -------
    usage: dict
        Keys are device ids as integers.
        Values are memory usage as integers in MB.
    """
    result = subprocess.check_output(
        [
            'nvidia-smi', '--query-gpu=memory.used',
            '--format=csv,nounits,noheader'
        ], encoding='utf-8')
    # Convert lines into a dictionary
    gpu_memory = [int(x) for x in result.strip().split('\n')]
    gpu_memory_map = dict(zip(range(len(gpu_memory)), gpu_memory))
    return gpu_memory_map

# %%
disc_params = list(dn_xz.parameters())+list(dn_xx.parameters()) +list(dn_zz.parameters())
disc_optimizer = torch.optim.Adam( disc_params, lr=learning_rate,betas = (0.5,0.999))
gen_params = list(gen.parameters()) + list(inf.parameters())
gen_optimizer = torch.optim.Adam(gen_params , lr = learning_rate, betas = (0.5,0.999))

# %%
# With every batch GPU usage increases 
# Didnt found rational reasons of such behaviour
def train(trainx):
    import gc
    epoch = 0
    nb_epochs = 100
    trainx = trainx[rng.permutation(trainx.shape[0])]
    FG, FD = [],[]
    i = 0
    
    bce = nn.BCELoss()
    sigmoid = nn.Sigmoid()
    while not False and epoch < nb_epochs:
    
        # construct randomly permuted minibatches
        # shuffling dataset
 
        train_loss_dis_xz, train_loss_dis_xx,  train_loss_dis_zz, \
        train_loss_dis, train_loss_gen, train_loss_enc = [0, 0, 0, 0, 0, 0]
    
            # Training
        for t in range(nr_batches_train):
            display_progression_epoch(t, nr_batches_train)
            
           
       
            ran_from = t * batch_size
            ran_to = (t + 1) * batch_size
        
           
            x = torch.Tensor(trainx[ran_from:ran_to])
            z = torch.Tensor(np.random.normal(size = [batch_size, latent_dim]))
            p_x = gen(z)
            q_z = inf(x)
        
          
            decoder_logit, _ = dn_xz(p_x, z)
            encoder_logit, _ = dn_xz(x , q_z)
    
          
            decoder_loss = bce(sigmoid(decoder_logit),torch.zeros_like(decoder_logit))
            encoder_loss =  bce(sigmoid(encoder_logit),torch.ones_like(encoder_logit))
            dis_loss_xz = torch.mean(encoder_loss+decoder_loss)
            decoder_loss2 =  bce(sigmoid(decoder_logit),torch.ones_like(decoder_logit))
            encoder_loss2 = bce(sigmoid(encoder_logit),torch.zeros_like(encoder_logit))
          
            gen_loss_xz = torch.mean((decoder_loss2))  + (torch.mean(encoder_loss2))
          
            rec_z = inf(p_x)
            rec_x = gen(q_z)
           
            x_logit_real,_ = dn_xx(x,x)
            x_logit_fake,_ = dn_xx(x,rec_x)
            z_logit_real,_ = dn_zz(z,z)
            z_logit_fake,_ = dn_zz(z,rec_z)
        
            x_sigmoid_real = bce(sigmoid(x_logit_real),torch.ones_like(x_logit_real))
            x_sigmoid_fake = bce(sigmoid(x_logit_fake),torch.zeros_like(x_logit_fake))
            x_sigmoid_real2 = bce(sigmoid(x_logit_real),torch.zeros_like(x_logit_real))
            x_sigmoid_fake2 = bce(sigmoid(x_logit_fake),torch.ones_like(x_logit_fake))
            z_sigmoid_real = bce(sigmoid(z_logit_real),torch.ones_like(z_logit_real))
            z_sigmoid_fake = bce(sigmoid(z_logit_fake),torch.zeros_like(z_logit_fake))
            z_sigmoid_real2 = bce(sigmoid(z_logit_real),torch.zeros_like(z_logit_real))
            z_sigmoid_fake2 = bce(sigmoid(z_logit_fake),torch.ones_like(z_logit_fake))
          
            dis_loss_x = torch.mean(x_sigmoid_real + x_sigmoid_fake)
            dis_loss_z = torch.mean(z_sigmoid_real + z_sigmoid_fake)
            disc_loss = dis_loss_xz + dis_loss_x + dis_loss_z
          
            cost_x = torch.mean(x_sigmoid_real2 + x_sigmoid_fake2) 
            cost_z = torch.mean(z_sigmoid_real2 + z_sigmoid_fake2)
            gen_loss = gen_loss_xz + cost_x  + cost_z
    
    
    
            gen_optimizer.zero_grad()
            gen_loss.backward(retain_graph = True)
            gen_optimizer.step()
            f_g = [gen_loss.data, gen_loss_xz.data, cost_x.data ,cost_z.data]
            
            disc_optimizer.zero_grad()
            disc_loss.backward(retain_graph = False)
            disc_optimizer.step()
        
            disc_loss.detach()
            gen_loss.detach()
            torch.cuda.empty_cache()
            gc.collect()
            f_d = disc_loss.data
            
            FG.append(f_g)
            FD.append(f_d)
            i+=1
            print("Happy New %d Batch!"%i)
            print("Memory map: " + str(get_gpu_memory_map()))
    
        print("epoch %d iter %d: discloss %f genloss %f adv_x %f recons_x %f " % (epoch, i, f_d, f_g[0], f_g[1], f_g[2]))
    
train(trainx)
# Out:
# Happy New 1 Batch!
# Memory map: {0: 1237}
# Happy New 2 Batch!
# Memory map: {0: 1239}
# Happy New 3 Batch!
# Memory map: {0: 1205}
# Happy New 4 Batch!
# Memory map: {0: 1206}
# Happy New 5 Batch!
# Memory map: {0: 1205}
# Happy New 6 Batch!
# Memory map: {0: 1205}
# Happy New 7 Batch!
# Memory map: {0: 1204}
# Happy New 8 Batch!
# Memory map: {0: 1205}
# Happy New 9 Batch!
# Memory map: {0: 1205}
# Happy New 10 Batch!
# Memory map: {0: 1206}
# Happy New 11 Batch!
# Memory map: {0: 1206}
# Happy New 12 Batch!
# Memory map: {0: 1205}
# Happy New 13 Batch!
# Memory map: {0: 1206}
# Happy New 14 Batch!
# Memory map: {0: 1206}
# Happy New 15 Batch!
# Memory map: {0: 1206}
# Happy New 16 Batch!
# Memory map: {0: 1205}
# Happy New 17 Batch!
# Memory map: {0: 1206}
# Happy New 18 Batch!
# Memory map: {0: 1206}
# Happy New 19 Batch!
# Memory map: {0: 1206}
# Happy New 20 Batch!
# Memory map: {0: 1207}
# Happy New 21 Batch!
# Memory map: {0: 1206}
# Happy New 22 Batch!
# Memory map: {0: 1205}
# Happy New 23 Batch!
# Memory map: {0: 1205}
# Happy New 24 Batch!
# Memory map: {0: 1205}
# Happy New 25 Batch!
# Memory map: {0: 1206}
# Happy New 26 Batch!
# Memory map: {0: 1203}
# Happy New 27 Batch!
# Memory map: {0: 1202}
# Happy New 28 Batch!
# Memory map: {0: 1201}
# Happy New 29 Batch!
# Memory map: {0: 1201}
# Happy New 30 Batch!
# Memory map: {0: 1202}
# Happy New 31 Batch!
# Memory map: {0: 1201}
# Happy New 32 Batch!
# Memory map: {0: 1201}
# Happy New 33 Batch!
# Memory map: {0: 1201}
# Happy New 34 Batch!
# Memory map: {0: 1201}
# Happy New 35 Batch!
# Memory map: {0: 1200}
# Happy New 36 Batch!
# Memory map: {0: 1201}
# Happy New 37 Batch!
# Memory map: {0: 1201}
# Happy New 38 Batch!
# Memory map: {0: 1201}
# Happy New 39 Batch!
# Memory map: {0: 1202}
# Happy New 40 Batch!
# Memory map: {0: 1201}
# Happy New 41 Batch!
# Memory map: {0: 1201}
# Happy New 42 Batch!
# Memory map: {0: 1201}
# Happy New 43 Batch!
# Memory map: {0: 1202}
# Happy New 44 Batch!
# Memory map: {0: 1202}
# Happy New 45 Batch!
# Memory map: {0: 1202}
# Happy New 46 Batch!
# Memory map: {0: 1202}
# Happy New 47 Batch!
# Memory map: {0: 1203}
# Happy New 48 Batch!
# Memory map: {0: 1202}
# Happy New 49 Batch!
# Memory map: {0: 1202}
# Happy New 50 Batch!
# Memory map: {0: 1202}
# Happy New 51 Batch!
# Memory map: {0: 1203}
# Happy New 52 Batch!
# Memory map: {0: 1202}
# Happy New 53 Batch!
# Memory map: {0: 1201}
# Happy New 54 Batch!
# Memory map: {0: 1201}
# Happy New 55 Batch!
# Memory map: {0: 1201}
# Happy New 56 Batch!
# Memory map: {0: 1201}
# Happy New 57 Batch!
# Memory map: {0: 1202}
# Happy New 58 Batch!
# Memory map: {0: 1202}
# Happy New 59 Batch!
# Memory map: {0: 1202}
# Happy New 60 Batch!
# Memory map: {0: 1202}
# Happy New 61 Batch!
# Memory map: {0: 1202}
# Happy New 62 Batch!
# Memory map: {0: 1203}
# Happy New 63 Batch!
# Memory map: {0: 1202}
# Happy New 64 Batch!
# Memory map: {0: 1201}
# Happy New 65 Batch!
# Memory map: {0: 1201}
# Happy New 66 Batch!
# Memory map: {0: 1201}
# Happy New 67 Batch!
# Memory map: {0: 1201}
# Happy New 68 Batch!
# Memory map: {0: 1202}
# Happy New 69 Batch!
# Memory map: {0: 1203}
# Happy New 70 Batch!
# Memory map: {0: 1203}
# Happy New 71 Batch!
# Memory map: {0: 1203}
# Happy New 72 Batch!
# Memory map: {0: 1203}
# Happy New 73 Batch!
# Memory map: {0: 1202}
# Happy New 74 Batch!
# Memory map: {0: 1202}
# Happy New 75 Batch!
# Memory map: {0: 1202}
# Happy New 76 Batch!
# Memory map: {0: 1203}
# Happy New 77 Batch!
# Memory map: {0: 1203}
# Happy New 78 Batch!
# Memory map: {0: 1202}
# Happy New 79 Batch!
# Memory map: {0: 1202}
# Happy New 80 Batch!
# Memory map: {0: 1201}
# Happy New 81 Batch!
# Memory map: {0: 1201}
# Happy New 82 Batch!
# Memory map: {0: 1200}
# Happy New 83 Batch!
# Memory map: {0: 1202}
# Happy New 84 Batch!
# Memory map: {0: 1203}
# Happy New 85 Batch!
# Memory map: {0: 1202}
# Happy New 86 Batch!
# Memory map: {0: 1203}
# Happy New 87 Batch!
# Memory map: {0: 1201}
# Happy New 88 Batch!
# Memory map: {0: 1201}
# Happy New 89 Batch!
# Memory map: {0: 1201}
# Happy New 90 Batch!
# Memory map: {0: 1202}
# Happy New 91 Batch!
# Memory map: {0: 1201}
# Happy New 92 Batch!
# Memory map: {0: 1201}
# Happy New 93 Batch!
# Memory map: {0: 1201}
# Happy New 94 Batch!
# Memory map: {0: 1201}
# Happy New 95 Batch!
# Memory map: {0: 1202}
# Happy New 96 Batch!
# Memory map: {0: 1202}
# Happy New 97 Batch!
# Memory map: {0: 1201}
# Happy New 98 Batch!
# Memory map: {0: 1201}
# Happy New 99 Batch!
# Memory map: {0: 1201}
# Happy New 100 Batch!
# Memory map: {0: 1201}
# Happy New 101 Batch!
# Memory map: {0: 1200}
# Happy New 102 Batch!
# Memory map: {0: 1201}
# Happy New 103 Batch!
# Memory map: {0: 1202}
# Happy New 104 Batch!
# Memory map: {0: 1206}
# Happy New 105 Batch!
# Memory map: {0: 1206}
# Happy New 106 Batch!
# Memory map: {0: 1205}
# Happy New 107 Batch!
# Memory map: {0: 1205}
# Happy New 108 Batch!
# Memory map: {0: 1205}
# Happy New 109 Batch!
# Memory map: {0: 1206}
# Happy New 110 Batch!
# Memory map: {0: 1207}
# Happy New 111 Batch!
# Memory map: {0: 1207}
# Happy New 112 Batch!
# Memory map: {0: 1207}
# Happy New 113 Batch!
# Memory map: {0: 1206}
# Happy New 114 Batch!
# Memory map: {0: 1206}
# Happy New 115 Batch!
# Memory map: {0: 1207}
# Happy New 116 Batch!
# Memory map: {0: 1207}
# Happy New 117 Batch!
# Memory map: {0: 1206}
# Happy New 118 Batch!
# Memory map: {0: 1207}
# Happy New 119 Batch!
# Memory map: {0: 1207}
# Happy New 120 Batch!
# Memory map: {0: 1207}
# Happy New 121 Batch!
# Memory map: {0: 1207}
# Happy New 122 Batch!
# Memory map: {0: 1206}
# Happy New 123 Batch!
# Memory map: {0: 1206}
# Happy New 124 Batch!
# Memory map: {0: 1205}
# Happy New 125 Batch!
# Memory map: {0: 1205}
# Happy New 126 Batch!
# Memory map: {0: 1205}
# Happy New 127 Batch!
# Memory map: {0: 1205}
# Happy New 128 Batch!
# Memory map: {0: 1205}
# Happy New 129 Batch!
# Memory map: {0: 1205}
# Happy New 130 Batch!
# Memory map: {0: 1205}
# Happy New 131 Batch!
# Memory map: {0: 1205}
# Happy New 132 Batch!
# Memory map: {0: 1205}
# Happy New 133 Batch!
# Memory map: {0: 1205}
# Happy New 134 Batch!
# Memory map: {0: 1205}
# Happy New 135 Batch!
# Memory map: {0: 1205}
# Happy New 136 Batch!
# Memory map: {0: 1206}
# Happy New 137 Batch!
# Memory map: {0: 1207}
# Happy New 138 Batch!
# Memory map: {0: 1207}
# Happy New 139 Batch!
# Memory map: {0: 1207}
# Happy New 140 Batch!
# Memory map: {0: 1207}
# Happy New 141 Batch!
# Memory map: {0: 1206}
# Happy New 142 Batch!
# Memory map: {0: 1206}
# Happy New 143 Batch!
# Memory map: {0: 1205}
# Happy New 144 Batch!
# Memory map: {0: 1206}
# Happy New 145 Batch!
# Memory map: {0: 1206}
# Happy New 146 Batch!
# Memory map: {0: 1205}
# Happy New 147 Batch!
# Memory map: {0: 1206}
# Happy New 148 Batch!
# Memory map: {0: 1206}
# Happy New 149 Batch!
# Memory map: {0: 1206}
# Happy New 150 Batch!
# Memory map: {0: 1207}
# Happy New 151 Batch!
# Memory map: {0: 1206}
# Happy New 152 Batch!
# Memory map: {0: 1206}
# Happy New 153 Batch!
# Memory map: {0: 1207}
# Happy New 154 Batch!
# Memory map: {0: 1207}
# Happy New 155 Batch!
# Memory map: {0: 1207}
# Happy New 156 Batch!
# Memory map: {0: 1207}
# Happy New 157 Batch!
# Memory map: {0: 1207}
# Happy New 158 Batch!
# Memory map: {0: 1207}
# Happy New 159 Batch!
# Memory map: {0: 1206}
# Happy New 160 Batch!
# Memory map: {0: 1207}
# Happy New 161 Batch!
# Memory map: {0: 1206}
# Happy New 162 Batch!
# Memory map: {0: 1206}
# Happy New 163 Batch!
# Memory map: {0: 1207}
# Happy New 164 Batch!
# Memory map: {0: 1207}
# Happy New 165 Batch!
# Memory map: {0: 1207}
# Happy New 166 Batch!
# Memory map: {0: 1207}
# Happy New 167 Batch!
# Memory map: {0: 1207}
# Happy New 168 Batch!
# Memory map: {0: 1205}
# Happy New 169 Batch!
# Memory map: {0: 1206}
# Happy New 170 Batch!
# Memory map: {0: 1206}
# Happy New 171 Batch!
# Memory map: {0: 1205}
# Happy New 172 Batch!
# Memory map: {0: 1205}
# Happy New 173 Batch!
# Memory map: {0: 1205}
# Happy New 174 Batch!
# Memory map: {0: 1205}
# Happy New 175 Batch!
# Memory map: {0: 1201}
# Happy New 176 Batch!
# Memory map: {0: 1202}
# Happy New 177 Batch!
# Memory map: {0: 1203}
# Happy New 178 Batch!
# Memory map: {0: 1203}
# Happy New 179 Batch!
# Memory map: {0: 1203}
# Happy New 180 Batch!
# Memory map: {0: 1202}
# Happy New 181 Batch!
# Memory map: {0: 1203}
# Happy New 182 Batch!
# Memory map: {0: 1203}
# Happy New 183 Batch!
# Memory map: {0: 1202}
# Happy New 184 Batch!
# Memory map: {0: 1203}
# Happy New 185 Batch!
# Memory map: {0: 1203}
# Happy New 186 Batch!
# Memory map: {0: 1202}
# Happy New 187 Batch!
# Memory map: {0: 1203}
# Happy New 188 Batch!
# Memory map: {0: 1203}
# Happy New 189 Batch!
# Memory map: {0: 1203}
# Happy New 190 Batch!
# Memory map: {0: 1203}
# Happy New 191 Batch!
# Memory map: {0: 1203}
# Happy New 192 Batch!
# Memory map: {0: 1202}
# Happy New 193 Batch!
# Memory map: {0: 1202}
# Happy New 194 Batch!
# Memory map: {0: 1202}
# Happy New 195 Batch!
# Memory map: {0: 1203}
# Happy New 196 Batch!
# Memory map: {0: 1203}
# Happy New 197 Batch!
# Memory map: {0: 1203}
# Happy New 198 Batch!
# Memory map: {0: 1203}
# Happy New 199 Batch!
# Memory map: {0: 1203}
# Happy New 200 Batch!
# Memory map: {0: 1203}
# Happy New 201 Batch!
# Memory map: {0: 1203}
# Happy New 202 Batch!
# Memory map: {0: 1202}
# Happy New 203 Batch!
# Memory map: {0: 1203}
# Happy New 204 Batch!
# Memory map: {0: 1203}
# Happy New 205 Batch!
# Memory map: {0: 1200}
# Happy New 206 Batch!
# Memory map: {0: 1201}
# Happy New 207 Batch!
# Memory map: {0: 1201}
# Happy New 208 Batch!
# Memory map: {0: 1202}
# Happy New 209 Batch!
# Memory map: {0: 1202}
# Happy New 210 Batch!
# Memory map: {0: 1201}
# Happy New 211 Batch!
# Memory map: {0: 1202}
# Happy New 212 Batch!
# Memory map: {0: 1203}
# Happy New 213 Batch!
# Memory map: {0: 1202}
# Happy New 214 Batch!
# Memory map: {0: 1202}
# Happy New 215 Batch!
# Memory map: {0: 1202}
# Happy New 216 Batch!
# Memory map: {0: 1202}
# Happy New 217 Batch!
# Memory map: {0: 1201}
# Happy New 218 Batch!
# Memory map: {0: 1201}
# Happy New 219 Batch!
# Memory map: {0: 1202}
# Happy New 220 Batch!
# Memory map: {0: 1201}
# Happy New 221 Batch!
# Memory map: {0: 1201}
# Happy New 222 Batch!
# Memory map: {0: 1201}
# Happy New 223 Batch!
# Memory map: {0: 1202}
# Happy New 224 Batch!
# Memory map: {0: 1203}
# Happy New 225 Batch!
# Memory map: {0: 1202}
# Happy New 226 Batch!
# Memory map: {0: 1203}
# Happy New 227 Batch!
# Memory map: {0: 1202}
# Happy New 228 Batch!
# Memory map: {0: 1203}
# Happy New 229 Batch!
# Memory map: {0: 1203}
# Happy New 230 Batch!
# Memory map: {0: 1203}
# Happy New 231 Batch!
# Memory map: {0: 1203}
# Happy New 232 Batch!
# Memory map: {0: 1203}
# Happy New 233 Batch!
# Memory map: {0: 1203}
# Happy New 234 Batch!
# Memory map: {0: 1203}
# Happy New 235 Batch!
# Memory map: {0: 1203}
# Happy New 236 Batch!
# Memory map: {0: 1203}
# Happy New 237 Batch!
# Memory map: {0: 1202}
# Happy New 238 Batch!
# Memory map: {0: 1201}
# Happy New 239 Batch!
# Memory map: {0: 1202}
# Happy New 240 Batch!
# Memory map: {0: 1201}
# Happy New 241 Batch!
# Memory map: {0: 1201}
# Happy New 242 Batch!
# Memory map: {0: 1201}
# Happy New 243 Batch!
# Memory map: {0: 1202}
# Happy New 244 Batch!
# Memory map: {0: 1201}
# Happy New 245 Batch!
# Memory map: {0: 1201}
# Happy New 246 Batch!
# Memory map: {0: 1201}
# Happy New 247 Batch!
# Memory map: {0: 1201}
# Happy New 248 Batch!
# Memory map: {0: 1201}
# Happy New 249 Batch!
# Memory map: {0: 1201}
# Happy New 250 Batch!
# Memory map: {0: 1201}
# Happy New 251 Batch!
# Memory map: {0: 1201}
# Happy New 252 Batch!
# Memory map: {0: 1201}
# Happy New 253 Batch!
# Memory map: {0: 1202}
# Happy New 254 Batch!
# Memory map: {0: 1202}
# Happy New 255 Batch!
# Memory map: {0: 1203}
# Happy New 256 Batch!
# Memory map: {0: 1202}
# Happy New 257 Batch!
# Memory map: {0: 1202}
# Happy New 258 Batch!
# Memory map: {0: 1203}
# Happy New 259 Batch!
# Memory map: {0: 1202}
# Happy New 260 Batch!
# Memory map: {0: 1203}
# Happy New 261 Batch!
# Memory map: {0: 1204}
# Happy New 262 Batch!
# Memory map: {0: 1203}
# Happy New 263 Batch!
# Memory map: {0: 1203}
# Happy New 264 Batch!
# Memory map: {0: 1202}
# Happy New 265 Batch!
# Memory map: {0: 1203}
# Happy New 266 Batch!
# Memory map: {0: 1203}
# Happy New 267 Batch!
# Memory map: {0: 1203}
# Happy New 268 Batch!
# Memory map: {0: 1202}
# Happy New 269 Batch!
# Memory map: {0: 1201}
# Happy New 270 Batch!
# Memory map: {0: 1201}
# Happy New 271 Batch!
# Memory map: {0: 1201}
# Happy New 272 Batch!
# Memory map: {0: 1201}
# Happy New 273 Batch!
# Memory map: {0: 1200}
# Happy New 274 Batch!
# Memory map: {0: 1200}
# Happy New 275 Batch!
# Memory map: {0: 1201}
# Happy New 276 Batch!
# Memory map: {0: 1202}
# Happy New 277 Batch!
# Memory map: {0: 1202}
# Happy New 278 Batch!
# Memory map: {0: 1202}
# Happy New 279 Batch!
# Memory map: {0: 1203}
# Happy New 280 Batch!
# Memory map: {0: 1203}
# Happy New 281 Batch!
# Memory map: {0: 1203}
# Happy New 282 Batch!
# Memory map: {0: 1202}
# Happy New 283 Batch!
# Memory map: {0: 1201}
# Happy New 284 Batch!
# Memory map: {0: 1202}
# Happy New 285 Batch!
# Memory map: {0: 1201}
# Happy New 286 Batch!
# Memory map: {0: 1202}
# Happy New 287 Batch!
# Memory map: {0: 1203}
# Happy New 288 Batch!
# Memory map: {0: 1203}
# Happy New 289 Batch!
# Memory map: {0: 1203}
# Happy New 290 Batch!
# Memory map: {0: 1203}
# Happy New 291 Batch!
# Memory map: {0: 1202}
# Happy New 292 Batch!
# Memory map: {0: 1203}
# Happy New 293 Batch!
# Memory map: {0: 1203}
# Happy New 294 Batch!
# Memory map: {0: 1202}
# Happy New 295 Batch!
# Memory map: {0: 1201}
# Happy New 296 Batch!
# Memory map: {0: 1202}
# Happy New 297 Batch!
# Memory map: {0: 1203}
# Happy New 298 Batch!
# Memory map: {0: 1202}
# Happy New 299 Batch!
# Memory map: {0: 1201}
# Happy New 300 Batch!
# Memory map: {0: 1201}
# Happy New 301 Batch!
# Memory map: {0: 1201}
# Happy New 302 Batch!
# Memory map: {0: 1201}
# Happy New 303 Batch!
# Memory map: {0: 1202}
# Happy New 304 Batch!
# Memory map: {0: 1201}
# Happy New 305 Batch!
# Memory map: {0: 1196}
# Happy New 306 Batch!
# Memory map: {0: 1197}
# Happy New 307 Batch!
# Memory map: {0: 1197}
# Happy New 308 Batch!
# Memory map: {0: 1196}
# Happy New 309 Batch!
# Memory map: {0: 1197}
# Happy New 310 Batch!
# Memory map: {0: 1198}
# Happy New 311 Batch!
# Memory map: {0: 1198}
# Happy New 312 Batch!
# Memory map: {0: 1198}
# Happy New 313 Batch!
# Memory map: {0: 1199}
# Happy New 314 Batch!
# Memory map: {0: 1199}
# Happy New 315 Batch!
# Memory map: {0: 1198}
# Happy New 316 Batch!
# Memory map: {0: 1199}
# Happy New 317 Batch!
# Memory map: {0: 1200}
# Happy New 318 Batch!
# Memory map: {0: 1198}
# Happy New 319 Batch!
# Memory map: {0: 1199}
# Happy New 320 Batch!
# Memory map: {0: 1198}
# Happy New 321 Batch!
# Memory map: {0: 1197}
# Happy New 322 Batch!
# Memory map: {0: 1197}
# Happy New 323 Batch!
# Memory map: {0: 1197}
# Happy New 324 Batch!
# Memory map: {0: 1197}
# Happy New 325 Batch!
# Memory map: {0: 1197}
# Happy New 326 Batch!
# Memory map: {0: 1197}
# Happy New 327 Batch!
# Memory map: {0: 1198}
# Happy New 328 Batch!
# Memory map: {0: 1197}
# Happy New 329 Batch!
# Memory map: {0: 1197}
# Happy New 330 Batch!
# Memory map: {0: 1197}
# Happy New 331 Batch!
# Memory map: {0: 1197}
# Happy New 332 Batch!
# Memory map: {0: 1197}
# Happy New 333 Batch!
# Memory map: {0: 1197}
# Happy New 334 Batch!
# Memory map: {0: 1198}
# Happy New 335 Batch!
# Memory map: {0: 1198}
# Happy New 336 Batch!
# Memory map: {0: 1199}
# Happy New 337 Batch!
# Memory map: {0: 1198}
# Happy New 338 Batch!
# Memory map: {0: 1198}
# Happy New 339 Batch!
# Memory map: {0: 1196}
# Happy New 340 Batch!
# Memory map: {0: 1198}
# Happy New 341 Batch!
# Memory map: {0: 1197}
# Happy New 342 Batch!
# Memory map: {0: 1198}
# Happy New 343 Batch!
# Memory map: {0: 1198}
# Happy New 344 Batch!
# Memory map: {0: 1197}
# Happy New 345 Batch!
# Memory map: {0: 1197}
# Happy New 346 Batch!
# Memory map: {0: 1197}
# Happy New 347 Batch!
# Memory map: {0: 1197}
# Happy New 348 Batch!
# Memory map: {0: 1197}
# Happy New 349 Batch!
# Memory map: {0: 1197}
# Happy New 350 Batch!
# Memory map: {0: 1198}
# Happy New 351 Batch!
# Memory map: {0: 1197}
# Happy New 352 Batch!
# Memory map: {0: 1197}
# Happy New 353 Batch!
# Memory map: {0: 1197}
# Happy New 354 Batch!
# Memory map: {0: 1197}
# Happy New 355 Batch!
# Memory map: {0: 1197}
# Happy New 356 Batch!
# Memory map: {0: 1197}
# Happy New 357 Batch!
# Memory map: {0: 1197}
# Happy New 358 Batch!
# Memory map: {0: 1198}
# Happy New 359 Batch!
# Memory map: {0: 1198}
# Happy New 360 Batch!
# Memory map: {0: 1199}
# Happy New 361 Batch!
# Memory map: {0: 1198}
# Happy New 362 Batch!
# Memory map: {0: 1197}
# Happy New 363 Batch!
# Memory map: {0: 1201}
# Happy New 364 Batch!
# Memory map: {0: 1204}
# Happy New 365 Batch!
# Memory map: {0: 1203}
# Happy New 366 Batch!
# Memory map: {0: 1205}
# Happy New 367 Batch!
# Memory map: {0: 1203}
# Happy New 368 Batch!
# Memory map: {0: 1204}
# Happy New 369 Batch!
# Memory map: {0: 1205}
# Happy New 370 Batch!
# Memory map: {0: 1206}
# Happy New 371 Batch!
# Memory map: {0: 1206}
# Happy New 372 Batch!
# Memory map: {0: 1206}
# Happy New 373 Batch!
# Memory map: {0: 1204}
# Happy New 374 Batch!
# Memory map: {0: 1204}
# Happy New 375 Batch!
# Memory map: {0: 1205}
# Happy New 376 Batch!
# Memory map: {0: 1203}
# Happy New 377 Batch!
# Memory map: {0: 1204}
# Happy New 378 Batch!
# Memory map: {0: 1204}
# Happy New 379 Batch!
# Memory map: {0: 1204}
# Happy New 380 Batch!
# Memory map: {0: 1204}
# Happy New 381 Batch!
# Memory map: {0: 1204}
# Happy New 382 Batch!
# Memory map: {0: 1204}
# Happy New 383 Batch!
# Memory map: {0: 1204}
# Happy New 384 Batch!
# Memory map: {0: 1203}
# Happy New 385 Batch!
# Memory map: {0: 1204}
# Happy New 386 Batch!
# Memory map: {0: 1204}
# Happy New 387 Batch!
# Memory map: {0: 1205}
# Happy New 388 Batch!
# Memory map: {0: 1204}
# Happy New 389 Batch!
# Memory map: {0: 1204}
# Happy New 390 Batch!
# Memory map: {0: 1204}
# Happy New 391 Batch!
# Memory map: {0: 1204}
# Happy New 392 Batch!
# Memory map: {0: 1204}
# Happy New 393 Batch!
# Memory map: {0: 1204}
# Happy New 394 Batch!
# Memory map: {0: 1205}
# Happy New 395 Batch!
# Memory map: {0: 1206}
# Happy New 396 Batch!
# Memory map: {0: 1205}
# Happy New 397 Batch!
# Memory map: {0: 1204}
# Happy New 398 Batch!
# Memory map: {0: 1204}
# Happy New 399 Batch!
# Memory map: {0: 1204}
# Happy New 400 Batch!
# Memory map: {0: 1205}
# Happy New 401 Batch!
# Memory map: {0: 1205}
# Happy New 402 Batch!
# Memory map: {0: 1205}
# Happy New 403 Batch!
# Memory map: {0: 1204}
# Happy New 404 Batch!
# Memory map: {0: 1204}
# Happy New 405 Batch!
# Memory map: {0: 1204}
# Happy New 406 Batch!
# Memory map: {0: 1205}
# Happy New 407 Batch!
# Memory map: {0: 1204}
# Happy New 408 Batch!
# Memory map: {0: 1204}
# Happy New 409 Batch!
# Memory map: {0: 1204}
# Happy New 410 Batch!
# Memory map: {0: 1204}
# Happy New 411 Batch!
# Memory map: {0: 1204}
# Happy New 412 Batch!
# Memory map: {0: 1204}
# Happy New 413 Batch!
# Memory map: {0: 1204}
# Happy New 414 Batch!
# Memory map: {0: 1205}
# Happy New 415 Batch!
# Memory map: {0: 1205}
# Happy New 416 Batch!
# Memory map: {0: 1204}
# Happy New 417 Batch!
# Memory map: {0: 1205}
# Happy New 418 Batch!
# Memory map: {0: 1206}
# Happy New 419 Batch!
# Memory map: {0: 1204}
# Happy New 420 Batch!
# Memory map: {0: 1204}
# Happy New 421 Batch!
# Memory map: {0: 1204}
# Happy New 422 Batch!
# Memory map: {0: 1204}
# Happy New 423 Batch!
# Memory map: {0: 1205}
# Happy New 424 Batch!
# Memory map: {0: 1205}
# Happy New 425 Batch!
# Memory map: {0: 1204}
# Happy New 426 Batch!
# Memory map: {0: 1204}
# Happy New 427 Batch!
# Memory map: {0: 1204}
# Happy New 428 Batch!
# Memory map: {0: 1205}
# Happy New 429 Batch!
# Memory map: {0: 1204}
# Happy New 430 Batch!
# Memory map: {0: 1204}
# Happy New 431 Batch!
# Memory map: {0: 1204}
# Happy New 432 Batch!
# Memory map: {0: 1204}
# Happy New 433 Batch!
# Memory map: {0: 1204}
# Happy New 434 Batch!
# Memory map: {0: 1205}
# Happy New 435 Batch!
# Memory map: {0: 1204}
# Happy New 436 Batch!
# Memory map: {0: 1204}
# Happy New 437 Batch!
# Memory map: {0: 1204}
# Happy New 438 Batch!
# Memory map: {0: 1204}
# Happy New 439 Batch!
# Memory map: {0: 1204}
# Happy New 440 Batch!
# Memory map: {0: 1204}
# Happy New 441 Batch!
# Memory map: {0: 1204}
# Happy New 442 Batch!
# Memory map: {0: 1204}
# Happy New 443 Batch!
# Memory map: {0: 1204}
# Happy New 444 Batch!
# Memory map: {0: 1205}
# Happy New 445 Batch!
# Memory map: {0: 1206}
# Happy New 446 Batch!
# Memory map: {0: 1206}
# Happy New 447 Batch!
# Memory map: {0: 1206}
# Happy New 448 Batch!
# Memory map: {0: 1206}
# Happy New 449 Batch!
# Memory map: {0: 1205}
# Happy New 450 Batch!
# Memory map: {0: 1206}
# Happy New 451 Batch!
# Memory map: {0: 1206}
# Happy New 452 Batch!
# Memory map: {0: 1206}
# Happy New 453 Batch!
# Memory map: {0: 1206}
# Happy New 454 Batch!
# Memory map: {0: 1206}
# Happy New 455 Batch!
# Memory map: {0: 1206}
# Happy New 456 Batch!
# Memory map: {0: 1204}
# Happy New 457 Batch!
# Memory map: {0: 1204}
# Happy New 458 Batch!
# Memory map: {0: 1203}
# Happy New 459 Batch!
# Memory map: {0: 1204}
# Happy New 460 Batch!
# Memory map: {0: 1204}
# Happy New 461 Batch!
# Memory map: {0: 1204}
# Happy New 462 Batch!
# Memory map: {0: 1205}
# Happy New 463 Batch!
# Memory map: {0: 1206}
# Happy New 464 Batch!
# Memory map: {0: 1206}
# Happy New 465 Batch!
# Memory map: {0: 1206}
# Happy New 466 Batch!
# Memory map: {0: 1206}
# Happy New 467 Batch!
# Memory map: {0: 1205}
# Happy New 468 Batch!
# Memory map: {0: 1205}
# Happy New 469 Batch!
# Memory map: {0: 1204}
# Happy New 470 Batch!
# Memory map: {0: 1201}
# Happy New 471 Batch!
# Memory map: {0: 1202}
# Happy New 472 Batch!
# Memory map: {0: 1202}
# Happy New 473 Batch!
# Memory map: {0: 1201}
# Happy New 474 Batch!
# Memory map: {0: 1201}
# Happy New 475 Batch!
# Memory map: {0: 1201}
# Happy New 476 Batch!
# Memory map: {0: 1201}
# Happy New 477 Batch!
# Memory map: {0: 1200}
# Happy New 478 Batch!
# Memory map: {0: 1200}
# Happy New 479 Batch!
# Memory map: {0: 1200}
# Happy New 480 Batch!
# Memory map: {0: 1200}
# Happy New 481 Batch!
# Memory map: {0: 1200}
# Happy New 482 Batch!
# Memory map: {0: 1200}
# Happy New 483 Batch!
# Memory map: {0: 1201}
# Happy New 484 Batch!
# Memory map: {0: 1201}
# Happy New 485 Batch!
# Memory map: {0: 1201}
# Happy New 486 Batch!
# Memory map: {0: 1200}
# Happy New 487 Batch!
# Memory map: {0: 1200}
# Happy New 488 Batch!
# Memory map: {0: 1200}
# Happy New 489 Batch!
# Memory map: {0: 1200}
# Happy New 490 Batch!
# Memory map: {0: 1200}
# Happy New 491 Batch!
# Memory map: {0: 1200}
# Happy New 492 Batch!
# Memory map: {0: 1200}
# Happy New 493 Batch!
# Memory map: {0: 1200}
# Happy New 494 Batch!
# Memory map: {0: 1199}
# Happy New 495 Batch!
# Memory map: {0: 1200}
# Happy New 496 Batch!
# Memory map: {0: 1202}
# Happy New 497 Batch!
# Memory map: {0: 1202}
# Happy New 498 Batch!
# Memory map: {0: 1201}
# Happy New 499 Batch!
# Memory map: {0: 1201}
# Happy New 500 Batch!
# Memory map: {0: 1201}
# Happy New 501 Batch!
# Memory map: {0: 1200}
# Happy New 502 Batch!
# Memory map: {0: 1200}
# Happy New 503 Batch!
# Memory map: {0: 1200}
# Happy New 504 Batch!
# Memory map: {0: 1201}
# Happy New 505 Batch!
# Memory map: {0: 1202}
# Happy New 506 Batch!
# Memory map: {0: 1201}
# Happy New 507 Batch!
# Memory map: {0: 1202}
# Happy New 508 Batch!
# Memory map: {0: 1202}
# Happy New 509 Batch!
# Memory map: {0: 1202}
# Happy New 510 Batch!
# Memory map: {0: 1202}
# Happy New 511 Batch!
# Memory map: {0: 1201}
# Happy New 512 Batch!
# Memory map: {0: 1200}
# Happy New 513 Batch!
# Memory map: {0: 1199}
# Happy New 514 Batch!
# Memory map: {0: 1201}
# Happy New 515 Batch!
# Memory map: {0: 1202}
# Happy New 516 Batch!
# Memory map: {0: 1201}
# Happy New 517 Batch!
# Memory map: {0: 1200}
# Happy New 518 Batch!
# Memory map: {0: 1200}
# Happy New 519 Batch!
# Memory map: {0: 1201}
# Happy New 520 Batch!
# Memory map: {0: 1201}
# Happy New 521 Batch!
# Memory map: {0: 1200}
# Happy New 522 Batch!
# Memory map: {0: 1201}
# Happy New 523 Batch!
# Memory map: {0: 1201}
# Happy New 524 Batch!
# Memory map: {0: 1200}
# Happy New 525 Batch!
# Memory map: {0: 1200}
# Happy New 526 Batch!
# Memory map: {0: 1200}
# Happy New 527 Batch!
# Memory map: {0: 1200}
# Happy New 528 Batch!
# Memory map: {0: 1200}
# Happy New 529 Batch!
# Memory map: {0: 1200}
# Happy New 530 Batch!
# Memory map: {0: 1200}
# Happy New 531 Batch!
# Memory map: {0: 1200}
# Happy New 532 Batch!
# Memory map: {0: 1200}
# Happy New 533 Batch!
# Memory map: {0: 1200}
# Happy New 534 Batch!
# Memory map: {0: 1200}
# Happy New 535 Batch!
# Memory map: {0: 1201}
# Happy New 536 Batch!
# Memory map: {0: 1201}
# Happy New 537 Batch!
# Memory map: {0: 1201}
# Happy New 538 Batch!
# Memory map: {0: 1200}
# Happy New 539 Batch!
# Memory map: {0: 1200}
# Happy New 540 Batch!
# Memory map: {0: 1201}
# Happy New 541 Batch!
# Memory map: {0: 1200}
# Happy New 542 Batch!
# Memory map: {0: 1201}
# Happy New 543 Batch!
# Memory map: {0: 1200}
# Happy New 544 Batch!
# Memory map: {0: 1201}
# Happy New 545 Batch!
# Memory map: {0: 1202}
# Happy New 546 Batch!
# Memory map: {0: 1202}
# Happy New 547 Batch!
# Memory map: {0: 1202}
# Happy New 548 Batch!
# Memory map: {0: 1201}
# Happy New 549 Batch!
# Memory map: {0: 1202}
# Happy New 550 Batch!
# Memory map: {0: 1199}
# Happy New 551 Batch!
# Memory map: {0: 1200}
# Happy New 552 Batch!
# Memory map: {0: 1200}
# Happy New 553 Batch!
# Memory map: {0: 1200}
# Happy New 554 Batch!
# Memory map: {0: 1200}
# Happy New 555 Batch!
# Memory map: {0: 1201}
# Happy New 556 Batch!
# Memory map: {0: 1201}
# Happy New 557 Batch!
# Memory map: {0: 1201}
# Happy New 558 Batch!
# Memory map: {0: 1200}
# Happy New 559 Batch!
# Memory map: {0: 1200}
# Happy New 560 Batch!
# Memory map: {0: 1200}
# Happy New 561 Batch!
# Memory map: {0: 1200}
# Happy New 562 Batch!
# Memory map: {0: 1201}
# Happy New 563 Batch!
# Memory map: {0: 1200}
# Happy New 564 Batch!
# Memory map: {0: 1200}
# Happy New 565 Batch!
# Memory map: {0: 1200}
# Happy New 566 Batch!
# Memory map: {0: 1201}
# Happy New 567 Batch!
# Memory map: {0: 1200}
# Happy New 568 Batch!
# Memory map: {0: 1199}
# Happy New 569 Batch!
# Memory map: {0: 1200}
# Happy New 570 Batch!
# Memory map: {0: 1199}
# Happy New 571 Batch!
# Memory map: {0: 1201}
# Happy New 572 Batch!
# Memory map: {0: 1201}
# Happy New 573 Batch!
# Memory map: {0: 1201}
# Happy New 574 Batch!
# Memory map: {0: 1201}
# Happy New 575 Batch!
# Memory map: {0: 1202}
# Happy New 576 Batch!
# Memory map: {0: 1202}
# Happy New 577 Batch!
# Memory map: {0: 1201}
# Happy New 578 Batch!
# Memory map: {0: 1202}
# Happy New 579 Batch!
# Memory map: {0: 1202}
# Happy New 580 Batch!
# Memory map: {0: 1202}
# Happy New 581 Batch!
# Memory map: {0: 1202}
# Happy New 582 Batch!
# Memory map: {0: 1200}
# Happy New 583 Batch!
# Memory map: {0: 1200}
# Happy New 584 Batch!
# Memory map: {0: 1200}
# Happy New 585 Batch!
# Memory map: {0: 1199}
# Happy New 586 Batch!
# Memory map: {0: 1200}
# Happy New 587 Batch!
# Memory map: {0: 1201}
# Happy New 588 Batch!
# Memory map: {0: 1201}
# Happy New 589 Batch!
# Memory map: {0: 1201}
# Happy New 590 Batch!
# Memory map: {0: 1200}
# Happy New 591 Batch!
# Memory map: {0: 1200}
# Happy New 592 Batch!
# Memory map: {0: 1200}
# Happy New 593 Batch!
# Memory map: {0: 1201}
# Happy New 594 Batch!
# Memory map: {0: 1201}
# Happy New 595 Batch!
# Memory map: {0: 1200}
# Happy New 596 Batch!
# Memory map: {0: 1200}
# Happy New 597 Batch!
# Memory map: {0: 1201}
# Happy New 598 Batch!
# Memory map: {0: 1202}
# Happy New 599 Batch!
# Memory map: {0: 1201}
# Happy New 600 Batch!
# Memory map: {0: 1200}
# Happy New 601 Batch!
# Memory map: {0: 1201}
# Happy New 602 Batch!
# Memory map: {0: 1202}
# Happy New 603 Batch!
# Memory map: {0: 1202}
# Happy New 604 Batch!
# Memory map: {0: 1202}
# Happy New 605 Batch!
# Memory map: {0: 1202}
# Happy New 606 Batch!
# Memory map: {0: 1202}
# Happy New 607 Batch!
# Memory map: {0: 1202}
# Happy New 608 Batch!
# Memory map: {0: 1202}
# Happy New 609 Batch!
# Memory map: {0: 1202}
# Happy New 610 Batch!
# Memory map: {0: 1202}
# Happy New 611 Batch!
# Memory map: {0: 1202}
# Happy New 612 Batch!
# Memory map: {0: 1202}
# Happy New 613 Batch!
# Memory map: {0: 1201}
# Happy New 614 Batch!
# Memory map: {0: 1201}
# Happy New 615 Batch!
# Memory map: {0: 1202}
# Happy New 616 Batch!
# Memory map: {0: 1202}
# Happy New 617 Batch!
# Memory map: {0: 1202}
# Happy New 618 Batch!
# Memory map: {0: 1202}
# Happy New 619 Batch!
# Memory map: {0: 1200}
# Happy New 620 Batch!
# Memory map: {0: 1201}
# Happy New 621 Batch!
# Memory map: {0: 1200}
# Happy New 622 Batch!
# Memory map: {0: 1200}
# Happy New 623 Batch!
# Memory map: {0: 1201}
# Happy New 624 Batch!
# Memory map: {0: 1201}
# Happy New 625 Batch!
# Memory map: {0: 1200}
# Happy New 626 Batch!
# Memory map: {0: 1201}
# Happy New 627 Batch!
# Memory map: {0: 1201}
# Happy New 628 Batch!
# Memory map: {0: 1202}
# Happy New 629 Batch!
# Memory map: {0: 1203}
# Happy New 630 Batch!
# Memory map: {0: 1201}
# Happy New 631 Batch!
# Memory map: {0: 1202}
# Happy New 632 Batch!
# Memory map: {0: 1201}
# Happy New 633 Batch!
# Memory map: {0: 1201}
# Happy New 634 Batch!
# Memory map: {0: 1201}
# Happy New 635 Batch!
# Memory map: {0: 1200}
# Happy New 636 Batch!
# Memory map: {0: 1200}
# Happy New 637 Batch!
# Memory map: {0: 1200}
# Happy New 638 Batch!
# Memory map: {0: 1201}
# Happy New 639 Batch!
# Memory map: {0: 1201}
# Happy New 640 Batch!
# Memory map: {0: 1202}
# Happy New 641 Batch!
# Memory map: {0: 1200}
# Happy New 642 Batch!
# Memory map: {0: 1200}
# Happy New 643 Batch!
# Memory map: {0: 1201}
# Happy New 644 Batch!
# Memory map: {0: 1202}
# Happy New 645 Batch!
# Memory map: {0: 1202}
# Happy New 646 Batch!
# Memory map: {0: 1202}
# Happy New 647 Batch!
# Memory map: {0: 1199}
# Happy New 648 Batch!
# Memory map: {0: 1200}
# Happy New 649 Batch!
# Memory map: {0: 1200}
# Happy New 650 Batch!
# Memory map: {0: 1200}
# Happy New 651 Batch!
# Memory map: {0: 1199}
# Happy New 652 Batch!
# Memory map: {0: 1201}
# Happy New 653 Batch!
# Memory map: {0: 1200}
# Happy New 654 Batch!
# Memory map: {0: 1200}
# Happy New 655 Batch!
# Memory map: {0: 1201}
# Happy New 656 Batch!
# Memory map: {0: 1202}
# Happy New 657 Batch!
# Memory map: {0: 1200}
# Happy New 658 Batch!
# Memory map: {0: 1200}
# Happy New 659 Batch!
# Memory map: {0: 1199}
# Happy New 660 Batch!
# Memory map: {0: 1200}
# Happy New 661 Batch!
# Memory map: {0: 1200}
# Happy New 662 Batch!
# Memory map: {0: 1200}
# Happy New 663 Batch!
# Memory map: {0: 1201}
# Happy New 664 Batch!
# Memory map: {0: 1201}
# Happy New 665 Batch!
# Memory map: {0: 1201}
# Happy New 666 Batch!
# Memory map: {0: 1201}
# Happy New 667 Batch!
# Memory map: {0: 1201}
# Happy New 668 Batch!
# Memory map: {0: 1202}
# Happy New 669 Batch!
# Memory map: {0: 1199}
# Happy New 670 Batch!
# Memory map: {0: 1200}
# Happy New 671 Batch!
# Memory map: {0: 1201}
# Happy New 672 Batch!
# Memory map: {0: 1202}
# Happy New 673 Batch!
# Memory map: {0: 1201}
# Happy New 674 Batch!
# Memory map: {0: 1202}
# Happy New 675 Batch!
# Memory map: {0: 1202}
# Happy New 676 Batch!
# Memory map: {0: 1202}
# Happy New 677 Batch!
# Memory map: {0: 1202}
# Happy New 678 Batch!
# Memory map: {0: 1202}
# Happy New 679 Batch!
# Memory map: {0: 1202}
# Happy New 680 Batch!
# Memory map: {0: 1202}
# Happy New 681 Batch!
# Memory map: {0: 1202}
# Happy New 682 Batch!
# Memory map: {0: 1202}
# Happy New 683 Batch!
# Memory map: {0: 1202}
# Happy New 684 Batch!
# Memory map: {0: 1201}
# Happy New 685 Batch!
# Memory map: {0: 1202}
# Happy New 686 Batch!
# Memory map: {0: 1202}
# Happy New 687 Batch!
# Memory map: {0: 1202}
# Happy New 688 Batch!
# Memory map: {0: 1202}
# Happy New 689 Batch!
# Memory map: {0: 1202}
# Happy New 690 Batch!
# Memory map: {0: 1202}
# Happy New 691 Batch!
# Memory map: {0: 1202}
# Happy New 692 Batch!
# Memory map: {0: 1202}
# Happy New 693 Batch!
# Memory map: {0: 1202}
# Happy New 694 Batch!
# Memory map: {0: 1202}
# Happy New 695 Batch!
# Memory map: {0: 1202}
# Happy New 696 Batch!
# Memory map: {0: 1202}
# Happy New 697 Batch!
# Memory map: {0: 1200}
# Happy New 698 Batch!
# Memory map: {0: 1200}
# Happy New 699 Batch!
# Memory map: {0: 1201}
# Happy New 700 Batch!
# Memory map: {0: 1201}
# Happy New 701 Batch!
# Memory map: {0: 1201}
# Happy New 702 Batch!
# Memory map: {0: 1202}
# Happy New 703 Batch!
# Memory map: {0: 1201}
# Happy New 704 Batch!
# Memory map: {0: 1201}
# Happy New 705 Batch!
# Memory map: {0: 1202}
# Happy New 706 Batch!
# Memory map: {0: 1201}
# Happy New 707 Batch!
# Memory map: {0: 1200}
# Happy New 708 Batch!
# Memory map: {0: 1200}
# Happy New 709 Batch!
# Memory map: {0: 1200}
# Happy New 710 Batch!
# Memory map: {0: 1199}
# Happy New 711 Batch!
# Memory map: {0: 1200}
# Happy New 712 Batch!
# Memory map: {0: 1200}
# Happy New 713 Batch!
# Memory map: {0: 1200}
# Happy New 714 Batch!
# Memory map: {0: 1200}
# Happy New 715 Batch!
# Memory map: {0: 1199}
# Happy New 716 Batch!
# Memory map: {0: 1200}
# Happy New 717 Batch!
# Memory map: {0: 1200}
# Happy New 718 Batch!
# Memory map: {0: 1200}
# Happy New 719 Batch!
# Memory map: {0: 1200}
# Happy New 720 Batch!
# Memory map: {0: 1201}
# Happy New 721 Batch!
# Memory map: {0: 1202}
# Happy New 722 Batch!
# Memory map: {0: 1201}
# Happy New 723 Batch!
# Memory map: {0: 1201}
# Happy New 724 Batch!
# Memory map: {0: 1200}
# Happy New 725 Batch!
# Memory map: {0: 1200}
# Happy New 726 Batch!
# Memory map: {0: 1200}
# Happy New 727 Batch!
# Memory map: {0: 1200}
# Happy New 728 Batch!
# Memory map: {0: 1200}
# Happy New 729 Batch!
# Memory map: {0: 1200}
# Happy New 730 Batch!
# Memory map: {0: 1201}
# Happy New 731 Batch!
# Memory map: {0: 1200}
# Happy New 732 Batch!
# Memory map: {0: 1200}
# Happy New 733 Batch!
# Memory map: {0: 1200}
# Happy New 734 Batch!
# Memory map: {0: 1200}
# Happy New 735 Batch!
# Memory map: {0: 1200}
# Happy New 736 Batch!
# Memory map: {0: 1200}
# Happy New 737 Batch!
# Memory map: {0: 1200}
# Happy New 738 Batch!
# Memory map: {0: 1200}
# Happy New 739 Batch!
# Memory map: {0: 1201}
# Happy New 740 Batch!
# Memory map: {0: 1201}
# Happy New 741 Batch!
# Memory map: {0: 1201}
# Happy New 742 Batch!
# Memory map: {0: 1201}
# Happy New 743 Batch!
# Memory map: {0: 1201}
# Happy New 744 Batch!
# Memory map: {0: 1201}
# Happy New 745 Batch!
# Memory map: {0: 1202}
# Happy New 746 Batch!
# Memory map: {0: 1202}
# Happy New 747 Batch!
# Memory map: {0: 1201}
# Happy New 748 Batch!
# Memory map: {0: 1202}
# Happy New 749 Batch!
# Memory map: {0: 1202}
# Happy New 750 Batch!
# Memory map: {0: 1202}
# Happy New 751 Batch!
# Memory map: {0: 1202}
# Happy New 752 Batch!
# Memory map: {0: 1202}
# Happy New 753 Batch!
# Memory map: {0: 1202}
# Happy New 754 Batch!
# Memory map: {0: 1201}
# Happy New 755 Batch!
# Memory map: {0: 1202}
# Happy New 756 Batch!
# Memory map: {0: 1202}
# Happy New 757 Batch!
# Memory map: {0: 1202}
# Happy New 758 Batch!
# Memory map: {0: 1202}
# Happy New 759 Batch!
# Memory map: {0: 1202}
# Happy New 760 Batch!
# Memory map: {0: 1202}
# Happy New 761 Batch!
# Memory map: {0: 1202}
# Happy New 762 Batch!
# Memory map: {0: 1202}
# Happy New 763 Batch!
# Memory map: {0: 1200}
# Happy New 764 Batch!
# Memory map: {0: 1200}
# Happy New 765 Batch!
# Memory map: {0: 1199}
# Happy New 766 Batch!
# Memory map: {0: 1200}
# Happy New 767 Batch!
# Memory map: {0: 1200}
# Happy New 768 Batch!
# Memory map: {0: 1200}
# Happy New 769 Batch!
# Memory map: {0: 1200}
# Happy New 770 Batch!
# Memory map: {0: 1200}
# Happy New 771 Batch!
# Memory map: {0: 1200}
# Happy New 772 Batch!
# Memory map: {0: 1201}
# Happy New 773 Batch!
# Memory map: {0: 1205}
# Happy New 774 Batch!
# Memory map: {0: 1203}
# Happy New 775 Batch!
# Memory map: {0: 1205}
# Happy New 776 Batch!
# Memory map: {0: 1204}
# Happy New 777 Batch!
# Memory map: {0: 1204}
# Happy New 778 Batch!
# Memory map: {0: 1205}
# Happy New 779 Batch!
# Memory map: {0: 1205}
# Happy New 780 Batch!
# Memory map: {0: 1205}
# Happy New 781 Batch!
# Memory map: {0: 1206}
# Happy New 782 Batch!
# Memory map: {0: 1205}
# Happy New 783 Batch!
# Memory map: {0: 1205}
# Happy New 784 Batch!
# Memory map: {0: 1204}
# Happy New 785 Batch!
# Memory map: {0: 1204}
# Happy New 786 Batch!
# Memory map: {0: 1204}
# Happy New 787 Batch!
# Memory map: {0: 1204}
# Happy New 788 Batch!
# Memory map: {0: 1204}
# Happy New 789 Batch!
# Memory map: {0: 1204}
# Happy New 790 Batch!
# Memory map: {0: 1205}
# Happy New 791 Batch!
# Memory map: {0: 1204}
# Happy New 792 Batch!
# Memory map: {0: 1205}
# Happy New 793 Batch!
# Memory map: {0: 1206}
# Happy New 794 Batch!
# Memory map: {0: 1205}
# Happy New 795 Batch!
# Memory map: {0: 1205}
# Happy New 796 Batch!
# Memory map: {0: 1205}
# Happy New 797 Batch!
# Memory map: {0: 1204}
# Happy New 798 Batch!
# Memory map: {0: 1204}
# Happy New 799 Batch!
# Memory map: {0: 1205}
# Happy New 800 Batch!
# Memory map: {0: 1205}
# Happy New 801 Batch!
# Memory map: {0: 1206}
# Happy New 802 Batch!
# Memory map: {0: 1206}
# Happy New 803 Batch!
# Memory map: {0: 1204}
# Happy New 804 Batch!
# Memory map: {0: 1205}
# Happy New 805 Batch!
# Memory map: {0: 1204}
# Happy New 806 Batch!
# Memory map: {0: 1204}
# Happy New 807 Batch!
# Memory map: {0: 1205}
# Happy New 808 Batch!
# Memory map: {0: 1206}
# Happy New 809 Batch!
# Memory map: {0: 1205}
# Happy New 810 Batch!
# Memory map: {0: 1205}
# Happy New 811 Batch!
# Memory map: {0: 1204}
# Happy New 812 Batch!
# Memory map: {0: 1204}
# Happy New 813 Batch!
# Memory map: {0: 1204}
# Happy New 814 Batch!
# Memory map: {0: 1205}
# Happy New 815 Batch!
# Memory map: {0: 1205}
# Happy New 816 Batch!
# Memory map: {0: 1204}
# Happy New 817 Batch!
# Memory map: {0: 1204}
# Happy New 818 Batch!
# Memory map: {0: 1204}
# Happy New 819 Batch!
# Memory map: {0: 1204}
# Happy New 820 Batch!
# Memory map: {0: 1204}
# Happy New 821 Batch!
# Memory map: {0: 1204}
# Happy New 822 Batch!
# Memory map: {0: 1204}
# Happy New 823 Batch!
# Memory map: {0: 1204}
# Happy New 824 Batch!
# Memory map: {0: 1203}
# Happy New 825 Batch!
# Memory map: {0: 1201}
# Happy New 826 Batch!
# Memory map: {0: 1201}
# Happy New 827 Batch!
# Memory map: {0: 1201}
# Happy New 828 Batch!
# Memory map: {0: 1201}
# Happy New 829 Batch!
# Memory map: {0: 1201}
# Happy New 830 Batch!
# Memory map: {0: 1201}
# Happy New 831 Batch!
# Memory map: {0: 1201}
# Happy New 832 Batch!
# Memory map: {0: 1201}
# Happy New 833 Batch!
# Memory map: {0: 1201}
# Happy New 834 Batch!
# Memory map: {0: 1201}
# Happy New 835 Batch!
# Memory map: {0: 1201}
# Happy New 836 Batch!
# Memory map: {0: 1201}
# Happy New 837 Batch!
# Memory map: {0: 1200}
# Happy New 838 Batch!
# Memory map: {0: 1201}
# Happy New 839 Batch!
# Memory map: {0: 1201}
# Happy New 840 Batch!
# Memory map: {0: 1202}
# Happy New 841 Batch!
# Memory map: {0: 1202}
# Happy New 842 Batch!
# Memory map: {0: 1203}
# Happy New 843 Batch!
# Memory map: {0: 1202}
# Happy New 844 Batch!
# Memory map: {0: 1203}
# Happy New 845 Batch!
# Memory map: {0: 1202}
# Happy New 846 Batch!
# Memory map: {0: 1203}
# Happy New 847 Batch!
# Memory map: {0: 1202}
# Happy New 848 Batch!
# Memory map: {0: 1203}
# Happy New 849 Batch!
# Memory map: {0: 1202}
# Happy New 850 Batch!
# Memory map: {0: 1203}
# Happy New 851 Batch!
# Memory map: {0: 1202}
# Happy New 852 Batch!
# Memory map: {0: 1203}
# Happy New 853 Batch!
# Memory map: {0: 1203}
# Happy New 854 Batch!
# Memory map: {0: 1202}
# Happy New 855 Batch!
# Memory map: {0: 1203}
# Happy New 856 Batch!
# Memory map: {0: 1201}
# Happy New 857 Batch!
# Memory map: {0: 1202}
# Happy New 858 Batch!
# Memory map: {0: 1202}
# Happy New 859 Batch!
# Memory map: {0: 1201}
# Happy New 860 Batch!
# Memory map: {0: 1201}
# Happy New 861 Batch!
# Memory map: {0: 1201}
# Happy New 862 Batch!
# Memory map: {0: 1201}
# Happy New 863 Batch!
# Memory map: {0: 1202}
# Happy New 864 Batch!
# Memory map: {0: 1203}
# Happy New 865 Batch!
# Memory map: {0: 1201}
# Happy New 866 Batch!
# Memory map: {0: 1201}
# Happy New 867 Batch!
# Memory map: {0: 1201}
# Happy New 868 Batch!
# Memory map: {0: 1201}
# Happy New 869 Batch!
# Memory map: {0: 1202}
# Happy New 870 Batch!
# Memory map: {0: 1202}
# Happy New 871 Batch!
# Memory map: {0: 1202}
# Happy New 872 Batch!
# Memory map: {0: 1201}
# Happy New 873 Batch!
# Memory map: {0: 1201}
# Happy New 874 Batch!
# Memory map: {0: 1201}
# Happy New 875 Batch!
# Memory map: {0: 1201}
# Happy New 876 Batch!
# Memory map: {0: 1201}
# Happy New 877 Batch!
# Memory map: {0: 1202}
# Happy New 878 Batch!
# Memory map: {0: 1202}
# Happy New 879 Batch!
# Memory map: {0: 1203}
# Happy New 880 Batch!
# Memory map: {0: 1203}
# Happy New 881 Batch!
# Memory map: {0: 1202}
# Happy New 882 Batch!
# Memory map: {0: 1203}
# Happy New 883 Batch!
# Memory map: {0: 1203}
# Happy New 884 Batch!
# Memory map: {0: 1203}
# Happy New 885 Batch!
# Memory map: {0: 1203}
# Happy New 886 Batch!
# Memory map: {0: 1203}
# Happy New 887 Batch!
# Memory map: {0: 1203}
# Happy New 888 Batch!
# Memory map: {0: 1203}
# Happy New 889 Batch!
# Memory map: {0: 1203}
# Happy New 890 Batch!
# Memory map: {0: 1203}
# Happy New 891 Batch!
# Memory map: {0: 1203}
# Happy New 892 Batch!
# Memory map: {0: 1203}
# Happy New 893 Batch!
# Memory map: {0: 1201}
# Happy New 894 Batch!
# Memory map: {0: 1201}
# Happy New 895 Batch!
# Memory map: {0: 1201}
# Happy New 896 Batch!
# Memory map: {0: 1201}
# Happy New 897 Batch!
# Memory map: {0: 1201}
# Happy New 898 Batch!
# Memory map: {0: 1202}
# Happy New 899 Batch!
# Memory map: {0: 1201}
# Happy New 900 Batch!
# Memory map: {0: 1201}
# Happy New 901 Batch!
# Memory map: {0: 1201}
# Happy New 902 Batch!
# Memory map: {0: 1201}
# Happy New 903 Batch!
# Memory map: {0: 1201}
# Happy New 904 Batch!
# Memory map: {0: 1201}
# Happy New 905 Batch!
# Memory map: {0: 1202}
# Happy New 906 Batch!
# Memory map: {0: 1202}
# Happy New 907 Batch!
# Memory map: {0: 1201}
# Happy New 908 Batch!
# Memory map: {0: 1202}
# Happy New 909 Batch!
# Memory map: {0: 1203}
# Happy New 910 Batch!
# Memory map: {0: 1202}
# Happy New 911 Batch!
# Memory map: {0: 1201}
# Happy New 912 Batch!
# Memory map: {0: 1201}
# Happy New 913 Batch!
# Memory map: {0: 1200}
# Happy New 914 Batch!
# Memory map: {0: 1200}
# Happy New 915 Batch!
# Memory map: {0: 1200}
# Happy New 916 Batch!
# Memory map: {0: 1200}
# Happy New 917 Batch!
# Memory map: {0: 1200}
# Happy New 918 Batch!
# Memory map: {0: 1201}
# Happy New 919 Batch!
# Memory map: {0: 1201}
# Happy New 920 Batch!
# Memory map: {0: 1201}
# Happy New 921 Batch!
# Memory map: {0: 1202}
# Happy New 922 Batch!
# Memory map: {0: 1203}
# Happy New 923 Batch!
# Memory map: {0: 1203}
# Happy New 924 Batch!
# Memory map: {0: 1202}
# Happy New 925 Batch!
# Memory map: {0: 1202}
# Happy New 926 Batch!
# Memory map: {0: 1202}
# Happy New 927 Batch!
# Memory map: {0: 1202}
# Happy New 928 Batch!
# Memory map: {0: 1203}
# Happy New 929 Batch!
# Memory map: {0: 1203}
# Happy New 930 Batch!
# Memory map: {0: 1203}
# Happy New 931 Batch!
# Memory map: {0: 1203}
# Happy New 932 Batch!
# Memory map: {0: 1203}
# Happy New 933 Batch!
# Memory map: {0: 1203}
# Happy New 934 Batch!
# Memory map: {0: 1204}
# Happy New 935 Batch!
# Memory map: {0: 1201}
# Happy New 936 Batch!
# Memory map: {0: 1201}
# Happy New 937 Batch!
# Memory map: {0: 1201}
# Happy New 938 Batch!
# Memory map: {0: 1202}
# Happy New 939 Batch!
# Memory map: {0: 1200}
# Happy New 940 Batch!
# Memory map: {0: 1202}
# Happy New 941 Batch!
# Memory map: {0: 1201}
# Happy New 942 Batch!
# Memory map: {0: 1202}
# Happy New 943 Batch!
# Memory map: {0: 1203}
# Happy New 944 Batch!
# Memory map: {0: 1202}
# Happy New 945 Batch!
# Memory map: {0: 1203}
# Happy New 946 Batch!
# Memory map: {0: 1203}
# Happy New 947 Batch!
# Memory map: {0: 1203}
# Happy New 948 Batch!
# Memory map: {0: 1203}
# Happy New 949 Batch!
# Memory map: {0: 1201}
# Happy New 950 Batch!
# Memory map: {0: 1201}
# Happy New 951 Batch!
# Memory map: {0: 1202}
# Happy New 952 Batch!
# Memory map: {0: 1201}
# Happy New 953 Batch!
# Memory map: {0: 1200}
# Happy New 954 Batch!
# Memory map: {0: 1201}
# Happy New 955 Batch!
# Memory map: {0: 1202}
# Happy New 956 Batch!
# Memory map: {0: 1202}
# Happy New 957 Batch!
# Memory map: {0: 1203}
# Happy New 958 Batch!
# Memory map: {0: 1203}
# Happy New 959 Batch!
# Memory map: {0: 1203}
# Happy New 960 Batch!
# Memory map: {0: 1203}
# Happy New 961 Batch!
# Memory map: {0: 1203}
# Happy New 962 Batch!
# Memory map: {0: 1203}
# Happy New 963 Batch!
# Memory map: {0: 1203}
# Happy New 964 Batch!
# Memory map: {0: 1203}
# Happy New 965 Batch!
# Memory map: {0: 1203}
# Happy New 966 Batch!
# Memory map: {0: 1203}
# Happy New 967 Batch!
# Memory map: {0: 1203}
# Happy New 968 Batch!
# Memory map: {0: 1203}
# Happy New 969 Batch!
# Memory map: {0: 1203}
# Happy New 970 Batch!
# Memory map: {0: 1203}
# Happy New 971 Batch!
# Memory map: {0: 1203}
# Happy New 972 Batch!
# Memory map: {0: 1203}
# Happy New 973 Batch!
# Memory map: {0: 1203}
# Happy New 974 Batch!
# Memory map: {0: 1203}
# Happy New 975 Batch!
# Memory map: {0: 1202}
# Happy New 976 Batch!
# Memory map: {0: 1202}
# Happy New 977 Batch!
# Memory map: {0: 1202}
# Happy New 978 Batch!
# Memory map: {0: 1202}
# Happy New 979 Batch!
# Memory map: {0: 1203}
# Happy New 980 Batch!
# Memory map: {0: 1204}
# Happy New 981 Batch!
# Memory map: {0: 1201}
# Happy New 982 Batch!
# Memory map: {0: 1201}
# Happy New 983 Batch!
# Memory map: {0: 1201}
# Happy New 984 Batch!
# Memory map: {0: 1201}
# Happy New 985 Batch!
# Memory map: {0: 1201}
# Happy New 986 Batch!
# Memory map: {0: 1201}
# Happy New 987 Batch!
# Memory map: {0: 1202}
# Happy New 988 Batch!
# Memory map: {0: 1202}
# Happy New 989 Batch!
# Memory map: {0: 1201}
# Happy New 990 Batch!
# Memory map: {0: 1202}
# Happy New 991 Batch!
# Memory map: {0: 1202}
# Happy New 992 Batch!
# Memory map: {0: 1202}
# Happy New 993 Batch!
# Memory map: {0: 1201}
# Happy New 994 Batch!
# Memory map: {0: 1201}
# Happy New 995 Batch!
# Memory map: {0: 1202}
# Happy New 996 Batch!
# Memory map: {0: 1202}
# Happy New 997 Batch!
# Memory map: {0: 1202}
# Happy New 998 Batch!
# Memory map: {0: 1202}
# Happy New 999 Batch!
# Memory map: {0: 1201}
# Happy New 1000 Batch!
# Memory map: {0: 1201}
# Happy New 1001 Batch!
# Memory map: {0: 1201}
# Happy New 1002 Batch!
# Memory map: {0: 1202}
# Happy New 1003 Batch!
# Memory map: {0: 1201}
# Happy New 1004 Batch!
# Memory map: {0: 1202}
# Happy New 1005 Batch!
# Memory map: {0: 1202}
# Happy New 1006 Batch!
# Memory map: {0: 1202}
# Happy New 1007 Batch!
# Memory map: {0: 1203}
# Happy New 1008 Batch!
# Memory map: {0: 1202}
# Happy New 1009 Batch!
# Memory map: {0: 1201}
# Happy New 1010 Batch!
# Memory map: {0: 1202}
# Happy New 1011 Batch!
# Memory map: {0: 1201}
# Happy New 1012 Batch!
# Memory map: {0: 1202}
# Happy New 1013 Batch!
# Memory map: {0: 1201}
# Happy New 1014 Batch!
# Memory map: {0: 1202}
# Happy New 1015 Batch!
# Memory map: {0: 1203}
# Happy New 1016 Batch!
# Memory map: {0: 1202}
# Happy New 1017 Batch!
# Memory map: {0: 1201}
# Happy New 1018 Batch!
# Memory map: {0: 1201}
# Happy New 1019 Batch!
# Memory map: {0: 1202}
# Happy New 1020 Batch!
# Memory map: {0: 1203}
# Happy New 1021 Batch!
# Memory map: {0: 1201}
# Happy New 1022 Batch!
# Memory map: {0: 1202}
# Happy New 1023 Batch!
# Memory map: {0: 1203}
# Happy New 1024 Batch!
# Memory map: {0: 1202}
# Happy New 1025 Batch!
# Memory map: {0: 1201}
# Happy New 1026 Batch!
# Memory map: {0: 1202}
# Happy New 1027 Batch!
# Memory map: {0: 1201}
# Happy New 1028 Batch!
# Memory map: {0: 1201}
# Happy New 1029 Batch!
# Memory map: {0: 1202}
# Happy New 1030 Batch!
# Memory map: {0: 1202}
# Happy New 1031 Batch!
# Memory map: {0: 1203}
# Happy New 1032 Batch!
# Memory map: {0: 1203}
# Happy New 1033 Batch!
# Memory map: {0: 1203}
# Happy New 1034 Batch!
# Memory map: {0: 1201}
# Happy New 1035 Batch!
# Memory map: {0: 1201}
# Happy New 1036 Batch!
# Memory map: {0: 1201}
# Happy New 1037 Batch!
# Memory map: {0: 1202}
# Happy New 1038 Batch!
# Memory map: {0: 1202}
# Happy New 1039 Batch!
# Memory map: {0: 1203}
# Happy New 1040 Batch!
# Memory map: {0: 1203}
# Happy New 1041 Batch!
# Memory map: {0: 1204}
# Happy New 1042 Batch!
# Memory map: {0: 1202}
# Happy New 1043 Batch!
# Memory map: {0: 1202}
# Happy New 1044 Batch!
# Memory map: {0: 1202}
# Happy New 1045 Batch!
# Memory map: {0: 1203}
# Happy New 1046 Batch!
# Memory map: {0: 1203}
# Happy New 1047 Batch!
# Memory map: {0: 1203}
# Happy New 1048 Batch!
# Memory map: {0: 1203}
# Happy New 1049 Batch!
# Memory map: {0: 1202}
# Happy New 1050 Batch!
# Memory map: {0: 1203}
# Happy New 1051 Batch!
# Memory map: {0: 1203}
# Happy New 1052 Batch!
# Memory map: {0: 1202}
# Happy New 1053 Batch!
# Memory map: {0: 1201}
# Happy New 1054 Batch!
# Memory map: {0: 1202}
# Happy New 1055 Batch!
# Memory map: {0: 1202}
# Happy New 1056 Batch!
# Memory map: {0: 1201}
# Happy New 1057 Batch!
# Memory map: {0: 1201}
# Happy New 1058 Batch!
# Memory map: {0: 1201}
# Happy New 1059 Batch!
# Memory map: {0: 1202}
# Happy New 1060 Batch!
# Memory map: {0: 1201}
# Happy New 1061 Batch!
# Memory map: {0: 1202}
# Happy New 1062 Batch!
# Memory map: {0: 1201}
# Happy New 1063 Batch!
# Memory map: {0: 1201}
# Happy New 1064 Batch!
# Memory map: {0: 1202}
# Happy New 1065 Batch!
# Memory map: {0: 1202}
# Happy New 1066 Batch!
# Memory map: {0: 1202}
# Happy New 1067 Batch!
# Memory map: {0: 1202}
# Happy New 1068 Batch!
# Memory map: {0: 1202}
# Happy New 1069 Batch!
# Memory map: {0: 1202}
# Happy New 1070 Batch!
# Memory map: {0: 1202}
# Happy New 1071 Batch!
# Memory map: {0: 1202}
# Happy New 1072 Batch!
# Memory map: {0: 1202}
# Happy New 1073 Batch!
# Memory map: {0: 1202}
# Happy New 1074 Batch!
# Memory map: {0: 1201}
# Happy New 1075 Batch!
# Memory map: {0: 1200}
# Happy New 1076 Batch!
# Memory map: {0: 1200}
# Happy New 1077 Batch!
# Memory map: {0: 1200}
# Happy New 1078 Batch!
# Memory map: {0: 1201}
# Happy New 1079 Batch!
# Memory map: {0: 1201}
# Happy New 1080 Batch!
# Memory map: {0: 1200}
# Happy New 1081 Batch!
# Memory map: {0: 1200}
# Happy New 1082 Batch!
# Memory map: {0: 1201}
# Happy New 1083 Batch!
# Memory map: {0: 1202}
# Happy New 1084 Batch!
# Memory map: {0: 1202}
# Happy New 1085 Batch!
# Memory map: {0: 1201}
# Happy New 1086 Batch!
# Memory map: {0: 1202}
# Happy New 1087 Batch!
# Memory map: {0: 1200}
# Happy New 1088 Batch!
# Memory map: {0: 1200}
# Happy New 1089 Batch!
# Memory map: {0: 1201}
# Happy New 1090 Batch!
# Memory map: {0: 1202}
# Happy New 1091 Batch!
# Memory map: {0: 1201}
# Happy New 1092 Batch!
# Memory map: {0: 1200}
# Happy New 1093 Batch!
# Memory map: {0: 1200}
# Happy New 1094 Batch!
# Memory map: {0: 1201}
# Happy New 1095 Batch!
# Memory map: {0: 1201}
# Happy New 1096 Batch!
# Memory map: {0: 1202}
# Happy New 1097 Batch!
# Memory map: {0: 1202}
# Happy New 1098 Batch!
# Memory map: {0: 1202}
# Happy New 1099 Batch!
# Memory map: {0: 1202}
# Happy New 1100 Batch!
# Memory map: {0: 1200}
# Happy New 1101 Batch!
# Memory map: {0: 1200}
# Happy New 1102 Batch!
# Memory map: {0: 1201}
# Happy New 1103 Batch!
# Memory map: {0: 1200}
# Happy New 1104 Batch!
# Memory map: {0: 1200}
# Happy New 1105 Batch!
# Memory map: {0: 1201}
# Happy New 1106 Batch!
# Memory map: {0: 1202}
# Happy New 1107 Batch!
# Memory map: {0: 1202}
# Happy New 1108 Batch!
# Memory map: {0: 1202}
# Happy New 1109 Batch!
# Memory map: {0: 1202}
# Happy New 1110 Batch!
# Memory map: {0: 1201}
# Happy New 1111 Batch!
# Memory map: {0: 1201}
# Happy New 1112 Batch!
# Memory map: {0: 1200}
# Happy New 1113 Batch!
# Memory map: {0: 1200}
# Happy New 1114 Batch!
# Memory map: {0: 1201}
# Happy New 1115 Batch!
# Memory map: {0: 1201}
# Happy New 1116 Batch!
# Memory map: {0: 1200}
# ...
# Happy New 1215 Batch!
# Memory map: {0: 1202}
# Happy New 1216 Batch!
# Memory map: {0: 1201}
# Happy New 1217 Batch!
# Memory map: {0: 1202}
# Happy New 1218 Batch!
# Memory map: {0: 1201}
# Happy New 1219 Batch!
# Memory map: {0: 1202}
# Happy New 1220 Batch!
# Memory map: {0: 1201}
# Happy New 1221 Batch!
# Memory map: {0: 1200}
# Happy New 1222 Batch!
# Memory map: {0: 1201}
# Happy New 1223 Batch!
# Memory map: {0: 1205}
# Happy New 1224 Batch!
# Memory map: {0: 1205}
# Happy New 1225 Batch!
# Memory map: {0: 1206}
# Happy New 1226 Batch!
# Memory map: {0: 1203}
# Happy New 1227 Batch!
# Memory map: {0: 1205}
# Happy New 1228 Batch!
# Memory map: {0: 1205}
# Happy New 1229 Batch!
# Memory map: {0: 1204}
# Happy New 1230 Batch!
# Memory map: {0: 1204}
# Happy New 1231 Batch!
# Memory map: {0: 1204}
# Happy New 1232 Batch!
# Memory map: {0: 1204}
# Happy New 1233 Batch!
# Memory map: {0: 1204}
# Happy New 1234 Batch!
# Memory map: {0: 1204}
# Happy New 1235 Batch!
# Memory map: {0: 1205}
# Happy New 1236 Batch!
# Memory map: {0: 1205}
# Happy New 1237 Batch!
# Memory map: {0: 1204}
# Happy New 1238 Batch!
# Memory map: {0: 1204}
# Happy New 1239 Batch!
# Memory map: {0: 1205}
# Happy New 1240 Batch!
# Memory map: {0: 1204}
# Happy New 1241 Batch!
# Memory map: {0: 1204}
# Happy New 1242 Batch!
# Memory map: {0: 1205}
# Happy New 1243 Batch!
# Memory map: {0: 1204}
# Happy New 1244 Batch!
# Memory map: {0: 1204}
# Happy New 1245 Batch!
# Memory map: {0: 1205}
# Happy New 1246 Batch!
# Memory map: {0: 1204}
# Happy New 1247 Batch!
# Memory map: {0: 1204}
# Happy New 1248 Batch!
# Memory map: {0: 1204}
# Happy New 1249 Batch!
# Memory map: {0: 1205}
# Happy New 1250 Batch!
# Memory map: {0: 1206}
# Happy New 1251 Batch!
# Memory map: {0: 1205}
# Happy New 1252 Batch!
# Memory map: {0: 1205}
# Happy New 1253 Batch!
# Memory map: {0: 1204}
# Happy New 1254 Batch!
# Memory map: {0: 1203}
# Happy New 1255 Batch!
# Memory map: {0: 1204}
# Happy New 1256 Batch!
# Memory map: {0: 1204}
# Happy New 1257 Batch!
# Memory map: {0: 1205}
# Happy New 1258 Batch!
# Memory map: {0: 1204}
# Happy New 1259 Batch!
# Memory map: {0: 1205}
# Happy New 1260 Batch!
# Memory map: {0: 1204}
# Happy New 1261 Batch!
# Memory map: {0: 1202}
# Happy New 1262 Batch!
# Memory map: {0: 1201}
# Happy New 1263 Batch!
# Memory map: {0: 1201}
# Happy New 1264 Batch!
# Memory map: {0: 1201}
# Happy New 1265 Batch!
# Memory map: {0: 1201}
# Happy New 1266 Batch!
# Memory map: {0: 1201}
# Happy New 1267 Batch!
# Memory map: {0: 1201}
# Happy New 1268 Batch!
# Memory map: {0: 1201}
# Happy New 1269 Batch!
# Memory map: {0: 1201}
# Happy New 1270 Batch!
# Memory map: {0: 1201}
# Happy New 1271 Batch!
# Memory map: {0: 1202}
# Happy New 1272 Batch!
# Memory map: {0: 1203}
# Happy New 1273 Batch!
# Memory map: {0: 1202}
# Happy New 1274 Batch!
# Memory map: {0: 1202}
# Happy New 1275 Batch!
# Memory map: {0: 1202}
# Happy New 1276 Batch!
# Memory map: {0: 1201}
# Happy New 1277 Batch!
# Memory map: {0: 1200}
# Happy New 1278 Batch!
# Memory map: {0: 1202}
# Happy New 1279 Batch!
# Memory map: {0: 1202}
# Happy New 1280 Batch!
# Memory map: {0: 1203}
# Happy New 1281 Batch!
# Memory map: {0: 1203}
# Happy New 1282 Batch!
# Memory map: {0: 1201}
# Happy New 1283 Batch!
# Memory map: {0: 1201}
# Happy New 1284 Batch!
# Memory map: {0: 1200}
# Happy New 1285 Batch!
# Memory map: {0: 1201}
# Happy New 1286 Batch!
# Memory map: {0: 1201}
# Happy New 1287 Batch!
# Memory map: {0: 1202}
# Happy New 1288 Batch!
# Memory map: {0: 1202}
# Happy New 1289 Batch!
# Memory map: {0: 1202}
# Happy New 1290 Batch!
# Memory map: {0: 1202}
# Happy New 1291 Batch!
# Memory map: {0: 1202}
# Happy New 1292 Batch!
# Memory map: {0: 1203}
# Happy New 1293 Batch!
# Memory map: {0: 1202}
# Happy New 1294 Batch!
# Memory map: {0: 1203}
# Happy New 1295 Batch!
# Memory map: {0: 1201}
# Happy New 1296 Batch!
# Memory map: {0: 1201}
# Happy New 1297 Batch!
# Memory map: {0: 1201}
# Happy New 1298 Batch!
# Memory map: {0: 1201}
# Happy New 1299 Batch!
# Memory map: {0: 1201}
# Happy New 1300 Batch!
# Memory map: {0: 1201}
# Happy New 1301 Batch!
# Memory map: {0: 1201}
# Happy New 1302 Batch!
# Memory map: {0: 1201}
# Happy New 1303 Batch!
# Memory map: {0: 1201}
# Happy New 1304 Batch!
# Memory map: {0: 1202}
# Happy New 1305 Batch!
# Memory map: {0: 1202}
# Happy New 1306 Batch!
# Memory map: {0: 1203}
# Happy New 1307 Batch!
# Memory map: {0: 1202}
# Happy New 1308 Batch!
# Memory map: {0: 1203}
# Happy New 1309 Batch!
# Memory map: {0: 1203}
# Happy New 1310 Batch!
# Memory map: {0: 1200}
# Happy New 1311 Batch!
# Memory map: {0: 1201}
# Happy New 1312 Batch!
# Memory map: {0: 1201}
# Happy New 1313 Batch!
# Memory map: {0: 1201}
# Happy New 1314 Batch!
# Memory map: {0: 1202}
# Happy New 1315 Batch!
# Memory map: {0: 1201}
# Happy New 1316 Batch!
# Memory map: {0: 1201}
# Happy New 1317 Batch!
# Memory map: {0: 1201}
# Happy New 1318 Batch!
# Memory map: {0: 1201}
# Happy New 1319 Batch!
# Memory map: {0: 1201}
# Happy New 1320 Batch!
# Memory map: {0: 1201}
# Happy New 1321 Batch!
# Memory map: {0: 1201}
# Happy New 1322 Batch!
# Memory map: {0: 1202}
# Happy New 1323 Batch!
# Memory map: {0: 1201}
# Happy New 1324 Batch!
# Memory map: {0: 1202}
# Happy New 1325 Batch!
# Memory map: {0: 1202}
# Happy New 1326 Batch!
# Memory map: {0: 1203}
# Happy New 1327 Batch!
# Memory map: {0: 1201}
# Happy New 1328 Batch!
# Memory map: {0: 1201}
# Happy New 1329 Batch!
# Memory map: {0: 1201}
# Happy New 1330 Batch!
# Memory map: {0: 1202}
# Happy New 1331 Batch!
# Memory map: {0: 1202}
# Happy New 1332 Batch!
# Memory map: {0: 1201}
# Happy New 1333 Batch!
# Memory map: {0: 1201}
# Happy New 1334 Batch!
# Memory map: {0: 1201}
# Happy New 1335 Batch!
# Memory map: {0: 1201}
# Happy New 1336 Batch!
# Memory map: {0: 1201}
# Happy New 1337 Batch!
# Memory map: {0: 1201}
# Happy New 1338 Batch!
# Memory map: {0: 1202}
# Happy New 1339 Batch!
# Memory map: {0: 1202}
# Happy New 1340 Batch!
# Memory map: {0: 1202}
# Happy New 1341 Batch!
# Memory map: {0: 1201}
# Happy New 1342 Batch!
# Memory map: {0: 1201}
# Happy New 1343 Batch!
# Memory map: {0: 1202}
# Happy New 1344 Batch!
# Memory map: {0: 1202}
# Happy New 1345 Batch!
# Memory map: {0: 1201}
# Happy New 1346 Batch!
# Memory map: {0: 1201}
# Happy New 1347 Batch!
# Memory map: {0: 1201}
# Happy New 1348 Batch!
# Memory map: {0: 1201}
# Happy New 1349 Batch!
# Memory map: {0: 1202}
# Happy New 1350 Batch!
# Memory map: {0: 1202}
# Happy New 1351 Batch!
# Memory map: {0: 1203}
# Happy New 1352 Batch!
# Memory map: {0: 1203}
# Happy New 1353 Batch!
# Memory map: {0: 1202}
# Happy New 1354 Batch!
# Memory map: {0: 1200}
# Happy New 1355 Batch!
# Memory map: {0: 1200}
# Happy New 1356 Batch!
# Memory map: {0: 1199}
# Happy New 1357 Batch!
# Memory map: {0: 1200}
# Happy New 1358 Batch!
# Memory map: {0: 1200}
# Happy New 1359 Batch!
# Memory map: {0: 1200}
# Happy New 1360 Batch!
# Memory map: {0: 1200}
# Happy New 1361 Batch!
# Memory map: {0: 1200}
# Happy New 1362 Batch!
# Memory map: {0: 1200}
# Happy New 1363 Batch!
# Memory map: {0: 1201}
# Happy New 1364 Batch!
# Memory map: {0: 1202}
# Happy New 1365 Batch!
# Memory map: {0: 1201}
# Happy New 1366 Batch!
# Memory map: {0: 1202}
# Happy New 1367 Batch!
# Memory map: {0: 1202}
# Happy New 1368 Batch!
# Memory map: {0: 1201}
# Happy New 1369 Batch!
# Memory map: {0: 1201}
# Happy New 1370 Batch!
# Memory map: {0: 1202}
# Happy New 1371 Batch!
# Memory map: {0: 1201}
# Happy New 1372 Batch!
# Memory map: {0: 1200}
# Happy New 1373 Batch!
# Memory map: {0: 1200}
# Happy New 1374 Batch!
# Memory map: {0: 1201}
# Happy New 1375 Batch!
# Memory map: {0: 1201}
# Happy New 1376 Batch!
# Memory map: {0: 1201}
# Happy New 1377 Batch!
# Memory map: {0: 1200}
# Happy New 1378 Batch!
# Memory map: {0: 1200}
# Happy New 1379 Batch!
# Memory map: {0: 1200}
# Happy New 1380 Batch!
# Memory map: {0: 1200}
# Happy New 1381 Batch!
# Memory map: {0: 1200}
# Happy New 1382 Batch!
# Memory map: {0: 1201}
# Happy New 1383 Batch!
# Memory map: {0: 1200}
# Happy New 1384 Batch!
# Memory map: {0: 1200}
# Happy New 1385 Batch!
# Memory map: {0: 1201}
# Happy New 1386 Batch!
# Memory map: {0: 1201}
# Happy New 1387 Batch!
# Memory map: {0: 1201}
# Happy New 1388 Batch!
# Memory map: {0: 1201}
# Happy New 1389 Batch!
# Memory map: {0: 1200}
# Happy New 1390 Batch!
# Memory map: {0: 1200}
# Happy New 1391 Batch!
# Memory map: {0: 1200}
# Happy New 1392 Batch!
# Memory map: {0: 1201}
# Happy New 1393 Batch!
# Memory map: {0: 1200}
# Happy New 1394 Batch!
# Memory map: {0: 1200}
# Happy New 1395 Batch!
# Memory map: {0: 1200}
# Happy New 1396 Batch!
# Memory map: {0: 1200}
# Happy New 1397 Batch!
# Memory map: {0: 1199}
# Happy New 1398 Batch!
# Memory map: {0: 1200}
# Happy New 1399 Batch!
# Memory map: {0: 1200}
# Happy New 1400 Batch!
# Memory map: {0: 1199}
# Happy New 1401 Batch!
# Memory map: {0: 1201}
# Happy New 1402 Batch!
# Memory map: {0: 1201}
# Happy New 1403 Batch!
# Memory map: {0: 1201}
# Happy New 1404 Batch!
# Memory map: {0: 1202}
# Happy New 1405 Batch!
# Memory map: {0: 1200}
# Happy New 1406 Batch!
# Memory map: {0: 1200}
# Happy New 1407 Batch!
# Memory map: {0: 1200}
# Happy New 1408 Batch!
# Memory map: {0: 1201}
# Happy New 1409 Batch!
# Memory map: {0: 1199}
# Happy New 1410 Batch!
# Memory map: {0: 1200}
# Happy New 1411 Batch!
# Memory map: {0: 1201}
# Happy New 1412 Batch!
# Memory map: {0: 1202}
# Happy New 1413 Batch!
# Memory map: {0: 1202}
# Happy New 1414 Batch!
# Memory map: {0: 1201}
# Happy New 1415 Batch!
# Memory map: {0: 1202}
# Happy New 1416 Batch!
# Memory map: {0: 1201}
# Happy New 1417 Batch!
# Memory map: {0: 1201}
# Happy New 1418 Batch!
# Memory map: {0: 1201}
# Happy New 1419 Batch!
# Memory map: {0: 1201}
# Happy New 1420 Batch!
# Memory map: {0: 1200}
# Happy New 1421 Batch!
# Memory map: {0: 1200}
# Happy New 1422 Batch!
# Memory map: {0: 1200}
# Happy New 1423 Batch!
# Memory map: {0: 1200}
# Happy New 1424 Batch!
# Memory map: {0: 1200}
# Happy New 1425 Batch!
# Memory map: {0: 1200}
# Happy New 1426 Batch!
# Memory map: {0: 1201}
# Happy New 1427 Batch!
# Memory map: {0: 1201}
# Happy New 1428 Batch!
# Memory map: {0: 1202}
# Happy New 1429 Batch!
# Memory map: {0: 1201}
# Happy New 1430 Batch!
# Memory map: {0: 1202}
# Happy New 1431 Batch!
# Memory map: {0: 1202}
# Happy New 1432 Batch!
# Memory map: {0: 1201}
# Happy New 1433 Batch!
# Memory map: {0: 1200}
# Happy New 1434 Batch!
# Memory map: {0: 1200}
# Happy New 1435 Batch!
# Memory map: {0: 1201}
# Happy New 1436 Batch!
# Memory map: {0: 1200}
# Happy New 1437 Batch!
# Memory map: {0: 1201}
# Happy New 1438 Batch!
# Memory map: {0: 1200}
# Happy New 1439 Batch!
# Memory map: {0: 1200}
# Happy New 1440 Batch!
# Memory map: {0: 1200}
# Happy New 1441 Batch!
# Memory map: {0: 1200}
# Happy New 1442 Batch!
# Memory map: {0: 1200}
# Happy New 1443 Batch!
# Memory map: {0: 1200}
# Happy New 1444 Batch!
# Memory map: {0: 1200}
# Happy New 1445 Batch!
# Memory map: {0: 1201}
# Happy New 1446 Batch!
# Memory map: {0: 1201}
# Happy New 1447 Batch!
# Memory map: {0: 1200}
# Happy New 1448 Batch!
# Memory map: {0: 1200}
# Happy New 1449 Batch!
# Memory map: {0: 1201}
# Happy New 1450 Batch!
# Memory map: {0: 1201}
# Happy New 1451 Batch!
# Memory map: {0: 1202}
# Happy New 1452 Batch!
# Memory map: {0: 1202}
# Happy New 1453 Batch!
# Memory map: {0: 1202}
# Happy New 1454 Batch!
# Memory map: {0: 1202}
# Happy New 1455 Batch!
# Memory map: {0: 1200}
# Happy New 1456 Batch!
# Memory map: {0: 1200}
# Happy New 1457 Batch!
# Memory map: {0: 1200}
# Happy New 1458 Batch!
# Memory map: {0: 1200}
# Happy New 1459 Batch!
# Memory map: {0: 1200}
# Happy New 1460 Batch!
# Memory map: {0: 1200}
# Happy New 1461 Batch!
# Memory map: {0: 1200}
# Happy New 1462 Batch!
# Memory map: {0: 1200}
# Happy New 1463 Batch!
# Memory map: {0: 1200}
# Happy New 1464 Batch!
# Memory map: {0: 1200}
# Happy New 1465 Batch!
# Memory map: {0: 1201}
# Happy New 1466 Batch!
# Memory map: {0: 1199}
# Happy New 1467 Batch!
# Memory map: {0: 1200}
# Happy New 1468 Batch!
# Memory map: {0: 1200}
# Happy New 1469 Batch!
# Memory map: {0: 1200}
# Happy New 1470 Batch!
# Memory map: {0: 1200}
# Happy New 1471 Batch!
# Memory map: {0: 1200}
# Happy New 1472 Batch!
# Memory map: {0: 1200}
# Happy New 1473 Batch!
# Memory map: {0: 1200}
# Happy New 1474 Batch!
# Memory map: {0: 1200}
# Happy New 1475 Batch!
# Memory map: {0: 1200}
# Happy New 1476 Batch!
# Memory map: {0: 1200}
# Happy New 1477 Batch!
# Memory map: {0: 1200}
# Happy New 1478 Batch!
# Memory map: {0: 1200}
# Happy New 1479 Batch!
# Memory map: {0: 1201}
# Happy New 1480 Batch!
# Memory map: {0: 1201}
# Happy New 1481 Batch!
# Memory map: {0: 1201}
# Happy New 1482 Batch!
# Memory map: {0: 1202}
# Happy New 1483 Batch!
# Memory map: {0: 1202}
# Happy New 1484 Batch!
# Memory map: {0: 1202}
# Happy New 1485 Batch!
# Memory map: {0: 1202}
# Happy New 1486 Batch!
# Memory map: {0: 1202}
# Happy New 1487 Batch!
# Memory map: {0: 1202}
# Happy New 1488 Batch!
# Memory map: {0: 1201}
# Happy New 1489 Batch!
# Memory map: {0: 1200}
# Happy New 1490 Batch!
# Memory map: {0: 1200}
# Happy New 1491 Batch!
# Memory map: {0: 1201}
# Happy New 1492 Batch!
# Memory map: {0: 1200}
# Happy New 1493 Batch!
# Memory map: {0: 1200}
# Happy New 1494 Batch!
# Memory map: {0: 1201}
# Happy New 1495 Batch!
# Memory map: {0: 1200}
# Happy New 1496 Batch!
# Memory map: {0: 1201}
# Happy New 1497 Batch!
# Memory map: {0: 1200}
# Happy New 1498 Batch!
# Memory map: {0: 1200}
# Happy New 1499 Batch!
# Memory map: {0: 1200}
# Happy New 1500 Batch!
# Memory map: {0: 1200}
# Happy New 1501 Batch!
# Memory map: {0: 1201}
# Happy New 1502 Batch!
# Memory map: {0: 1201}
# Happy New 1503 Batch!
# Memory map: {0: 1200}
# Happy New 1504 Batch!
# Memory map: {0: 1200}
# Happy New 1505 Batch!
# Memory map: {0: 1200}
# Happy New 1506 Batch!
# Memory map: {0: 1200}
# Happy New 1507 Batch!
# Memory map: {0: 1201}
# Happy New 1508 Batch!
# Memory map: {0: 1202}
# Happy New 1509 Batch!
# Memory map: {0: 1200}
# Happy New 1510 Batch!
# Memory map: {0: 1200}
# Happy New 1511 Batch!
# Memory map: {0: 1200}
# Happy New 1512 Batch!
# Memory map: {0: 1201}
# Happy New 1513 Batch!
# Memory map: {0: 1201}
# Happy New 1514 Batch!
# Memory map: {0: 1201}
# Happy New 1515 Batch!
# Memory map: {0: 1202}
# Happy New 1516 Batch!
# Memory map: {0: 1201}
# Happy New 1517 Batch!
# Memory map: {0: 1200}
# Happy New 1518 Batch!
# Memory map: {0: 1200}
# Happy New 1519 Batch!
# Memory map: {0: 1201}
# Happy New 1520 Batch!
# Memory map: {0: 1202}
# Happy New 1521 Batch!
# Memory map: {0: 1201}
# Happy New 1522 Batch!
# Memory map: {0: 1202}
# Happy New 1523 Batch!
# Memory map: {0: 1202}
# Happy New 1524 Batch!
# Memory map: {0: 1201}
# Happy New 1525 Batch!
# Memory map: {0: 1202}
# Happy New 1526 Batch!
# Memory map: {0: 1201}
# Happy New 1527 Batch!
# Memory map: {0: 1200}
# Happy New 1528 Batch!
# Memory map: {0: 1200}
# Happy New 1529 Batch!
# Memory map: {0: 1200}
# Happy New 1530 Batch!
# Memory map: {0: 1201}
# Happy New 1531 Batch!
# Memory map: {0: 1202}
# Happy New 1532 Batch!
# Memory map: {0: 1202}
# Happy New 1533 Batch!
# Memory map: {0: 1202}
# Happy New 1534 Batch!
# Memory map: {0: 1202}
# Happy New 1535 Batch!
# Memory map: {0: 1201}
# Happy New 1536 Batch!
# Memory map: {0: 1200}
# Happy New 1537 Batch!
# Memory map: {0: 1200}
# Happy New 1538 Batch!
# Memory map: {0: 1200}
# Happy New 1539 Batch!
# Memory map: {0: 1200}
# Happy New 1540 Batch!
# Memory map: {0: 1201}
# Happy New 1541 Batch!
# Memory map: {0: 1200}
# Happy New 1542 Batch!
# Memory map: {0: 1200}
# Happy New 1543 Batch!
# Memory map: {0: 1200}
# Happy New 1544 Batch!
# Memory map: {0: 1200}
# Happy New 1545 Batch!
# Memory map: {0: 1200}
# Happy New 1546 Batch!
# Memory map: {0: 1200}
# Happy New 1547 Batch!
# Memory map: {0: 1200}
# Happy New 1548 Batch!
# Memory map: {0: 1200}
# Happy New 1549 Batch!
# Memory map: {0: 1201}
# Happy New 1550 Batch!
# Memory map: {0: 1201}
# Happy New 1551 Batch!
# Memory map: {0: 1201}
# Happy New 1552 Batch!
# Memory map: {0: 1201}
# Happy New 1553 Batch!
# Memory map: {0: 1202}
# Happy New 1554 Batch!
# Memory map: {0: 1201}
# Happy New 1555 Batch!
# Memory map: {0: 1202}
# Happy New 1556 Batch!
# Memory map: {0: 1201}
# Happy New 1557 Batch!
# Memory map: {0: 1200}
# Happy New 1558 Batch!
# Memory map: {0: 1200}
# Happy New 1559 Batch!
# Memory map: {0: 1200}
# Happy New 1560 Batch!
# Memory map: {0: 1201}
# Happy New 1561 Batch!
# Memory map: {0: 1202}
# Happy New 1562 Batch!
# Memory map: {0: 1202}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-dff52fd1670a> in <module>
#      97         print("epoch %d iter %d: discloss %f genloss %f adv_x %f recons_x %f " % (epoch, i, f_d, f_g[0], f_g[1], f_g[2]))
#      98
# ---> 99 train(trainx)
#
# <ipython-input-13-dff52fd1670a> in train(trainx)
#      95             print("Memory map: " + str(get_gpu_memory_map()))
#      96
# ---> 97         print("epoch %d iter %d: discloss %f genloss %f adv_x %f recons_x %f " % (epoch, i, f_d, f_g[0], f_g[1], f_g[2]))
#      98
#      99 train(trainx)
#
# NameError: name 'f_d' is not defined

# %% [markdown]
# ## Memory leakage
# For some reasons intermediate tensors calculated in dn_xz are saved in GPU memory and not removed by GC!
# For example, <class 'torch.Tensor'> torch.Size([32, 8704, 1, 1]) which most probably corresponds to "y" tensor in "dn_xz.forward()" definition

# %%
import gc
for obj in gc.get_objects():
    try:
        print(type(obj), obj.size())
    except:
        pass

# %%
"""keys = globals().keys()
for k in keys:
    print(k)
   """
# Out:
# 'keys = globals().keys()\nfor k in keys:\n    print(k)\n   '

# %%
#del gen_loss, disc_loss, 
print(get_gpu_memory_map())


del gen_loss, disc_loss
torch.cuda.empty_cache()
gc.collect()


print(get_gpu_memory_map())
# Out:
# {0: 1904}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9c6c1f61ac83> in <module>
#       3
#       4
# ----> 5 del gen_loss, disc_loss
#       6 torch.cuda.empty_cache()
#       7 gc.collect()
#
# NameError: name 'gen_loss' is not defined

# %%
#del gen_loss, disc_loss, 
print(get_gpu_memory_map())


del dn_xx
torch.cuda.empty_cache()
gc.collect()


print(get_gpu_memory_map())
# Out:
# {0: 1879}
# {0: 1879}

# %%
#del gen_loss, disc_loss, 
print(get_gpu_memory_map())


del gen
torch.cuda.empty_cache()
gc.collect()


print(get_gpu_memory_map())
# Out:
# {0: 1875}
# {0: 1874}
