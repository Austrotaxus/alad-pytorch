# %% [markdown]
# # ALAD - Toy examples¶
#
# This is the notebook that generated Figure 2 in "Adversarially learnt anomaly detection" Credits : https://github.com/ChunyuanLI/ALICE
#
# ## Imports

# %%
# %matplotlib inline

import os
import pdb

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm


import torch as torch
import torch.nn as nn

from utils.data_gmm import GMM_distribution, sample_GMM, plot_GMM
from utils.data_utils import shuffle, iter_data, ToyDataset
from tqdm import tqdm
import sklearn.datasets

# %%
""" parameters """

DATASET = '4gaussians' # 5gaussians, swiss_roll, s_curve
N_NOISY = 100


device = 'cpu'

n_epoch = 300
batch_size  = 1024
dataset_size_x = 512*4
dataset_size_z = 512*4

dataset_size_x_test = 512*2
dataset_size_z_test = 512*2

input_dim = 2
latent_dim = 2
eps_dim = 2

n_layer_disc  = 2
n_hidden_disc = 256
n_layer_gen   = 3
n_hidden_gen  = 256
n_layer_inf   = 2
n_hidden_inf  = 256

# %%
""" Create directory for results """
result_dir = 'results/alad_toy/'
directory = result_dir
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# ## Training dataset
#
# #### 4 or 5 GMM

# %%
""" Create dataset """

def four_five_gaussians(p1=0):
    # create X dataset
    global dataset_size_x
    means_x = map(lambda x:  np.array(x), [[2, 2],
                                          [-2, -2],
                                          [2, -2],
                                          [-2, 2],
                                           [0, 0]])
    
    means_x = list(means_x)
    std_x = 0.02
    variances_x = [np.eye(2) * std_x for _ in means_x]

    #contamination = 4.0*p/(1-p)
    priors_x = np.array([1.0, 1.0, 1.0, 1.0, p1])
    priors_x /= sum(priors_x)
    #print(priors_x)
    gaussian_mixture = GMM_distribution(means=means_x,
                                                   variances=variances_x,
                                                   priors=priors_x)
    dataset_x = sample_GMM(dataset_size_x, means_x, variances_x, priors_x, sources=('features', ))
    return dataset_x

# %% [markdown]
# You can control the level of the fifth gaussian in the training set with the $p$ parameter
#
# Generate training dataset

# %%
dataset_x = four_five_gaussians(p1=0.0)
save_path_x = result_dir + 'X_4gmm_data_train.png'

# %%
## input x
X_dataset  = dataset_x.data['samples']
X_targets = dataset_x.data['label']

fig_mx, ax = plt.subplots(nrows=1, ncols=1, figsize=(4.5, 4.5))
ax.scatter(X_dataset[:, 0], X_dataset[:, 1], c=cm.tab20(X_targets.astype(float)/input_dim/3.0),
           edgecolor='none', alpha=0.5)
#ax.set_xlim(-3, 3); ax.set_ylim(-3.5, 3.5)
ax.set_xlabel('$x_1$'); ax.set_ylabel('$x_2$')
ax.set_title("X distribution in the training set" )
ax.axis('on')
plt.savefig(save_path_x, transparent=True, bbox_inches='tight')
plt.show()

# %%
# create Z dataset
means_z = map(lambda x:  np.array(x), [[0, 0]])
means_z = list(means_z)
std_z = 1.0
variances_z = [np.eye(2) * std_z for _ in means_z]
priors_z = [1.0/len(means_z) for _ in means_z]

dataset_z = sample_GMM(dataset_size_z, means_z, variances_z, priors_z, sources=('features', ))
save_path_z = result_dir + 'Z_gmm_data_train.png'

##  input z
Z_dataset = dataset_z.data['samples']
Z_labels  = dataset_z.data['label']

fig_mx, ax = plt.subplots(nrows=1, ncols=1, figsize=(4.5, 4.5))
ax.scatter(Z_dataset[:, 0], Z_dataset[:, 1],
           edgecolor='none', alpha=0.5)
ax.set_xlim(-3, 3); ax.set_ylim(-3.5, 3.5)
ax.set_xlabel('$z_1$'); ax.set_ylabel('$z_2$')
ax.set_title("Z distribution in the training set")
ax.axis('on')
plt.savefig(save_path_z, transparent=True, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Networks

# %%
""" Networks """

# Models constructors takes tensor arguments only to get input shapes for networks


class Generative_Network(nn.Module):
    def __init__(self,x, input_dim,n_layer, n_hidden, eps_dim, reuse = False):
        super(Generative_Network, self).__init__()
        layers = []
        self.z = z.to(device)
        z_shape = list(z.shape)[1]
            
        layers.append(nn.Linear(z_shape, n_hidden).to(device))
        layers.append(nn.ReLU())
          
        for i in range(0, n_layer):
            layers.append(nn.Linear(n_hidden,n_hidden).to(device))
            layers.append(nn.ReLU().to(device))
            
        layers.append(nn.Linear(n_hidden,input_dim).to(device))
        self.gn = nn.Sequential(*layers)
           
            
    def forward(self,z):
        return self.gn(z)


class Inference_Network(nn.Module):
    def __init__(self, x, latent_dim,n_layer, n_hidden, eps_dim, reuse = False):
        super(Inference_Network, self).__init__()
        self.x = x.to(device)
        layers = []
        x_shape = list(x.shape)[1]
        layers.append(nn.Linear(x_shape, n_hidden).to(device))
        layers.append(nn.ReLU())
          
        for i in range(0, n_layer):
            layers.append(nn.Linear(n_hidden,n_hidden).to(device))
            layers.append(nn.ReLU().to(device))
            
        layers.append(nn.Linear(n_hidden,latent_dim).to(device))
        self.infn = nn.Sequential(*layers)
            
    def forward(self,x):
        return self.infn(x)

    
class Data_Network_xz(nn.Module,):
    def __init__(self,x, z, n_layers=2, n_hidden=128, activation_fn=None,reuse=False):
        super(Data_Network_xz, self).__init__()
        layers = []
        
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.activation_fn = activation_fn
        self.reuse = reuse
        self.x = x.to(device)
        self.z = z.to(device)
        self.h = torch.cat((x, z), 1).to(device)
        
        h_shape = list(self.h.shape)[1]
        
        layers.append(nn.Linear(h_shape, n_hidden).to(device))
        layers.append(nn.ReLU())
          
        for i in range(0, n_layers):
            layers.append(nn.Linear(n_hidden,n_hidden).to(device))
            layers.append(nn.ReLU().to(device))
            
        layers.append(nn.Linear(n_hidden,1).to(device))
        
        if activation_fn:
            layers.append(activation_fn.to(device))
            
        self.dn_xz = nn.Sequential(*layers)
         
        
    def forward(self,x,z):
        h = torch.cat((x,z), 1).to(device)
        res = self.dn_xz(h)
        return res
    
    
class Data_Network_xx(nn.Module):
    def __init__(self,x, x_hat, n_layers=1, n_hidden=128, activation_fn=None,reuse=False):
        super(Data_Network_xx, self).__init__()
        layers = []
        self.h = torch.cat( (x, x_hat), 1).to(device)
        h_shape = list(self.h.shape)[1]
        
        layers.append(nn.Linear(h_shape, n_hidden).to(device))
        layers.append(nn.ReLU())
          
        for i in range(0, n_layers):
            layers.append(nn.Linear(n_hidden,n_hidden).to(device))
            layers.append(nn.ReLU().to(device))
            
        layers.append(nn.Linear(n_hidden,1).to(device))
        if activation_fn:
            layers.append(activation_fn.to(device))
        self.dn_xx = nn.Sequential(*layers)
        
    def forward(self,x,x_hat):
        h = torch.cat( (x, x_hat), 1).to(device)
        res = self.dn_xx(h)
        return res
    
    
class Data_Network_zz(nn.Module):
    def __init__(self,z, z_prime, n_layers=1, n_hidden=128, activation_fn=None,reuse=False):
        super(Data_Network_zz, self).__init__()
        layers = []
        self.h = torch.cat( (z, z_prime), 1).to(device)
        h_shape = list(self.h.shape)[1]
        
        layers.append(nn.Linear(h_shape, n_hidden).to(device))
        layers.append(nn.ReLU())
          
        for i in range(0, n_layers):
            layers.append(nn.Linear(n_hidden,n_hidden).to(device))
            layers.append(nn.ReLU().to(device))
            
        layers.append(nn.Linear(n_hidden,1).to(device))
        if activation_fn:
            layers.append(activation_fn.to(device))
        self.dn_zz = nn.Sequential(*layers)
        
    def forward(self, z, z_prime):
        h = torch.cat( (z, z_prime), 1).to(device)
        res = self.dn_zz(h)
        return res

# %%
x = torch.ones([batch_size, input_dim],dtype = torch.float)
z = torch.ones([batch_size, latent_dim],dtype = torch.float)   
# decoder and encoder
gen = Generative_Network(z, input_dim , n_layer_gen, n_hidden_gen, eps_dim)
inf = Inference_Network(x, latent_dim, n_layer_inf, n_hidden_inf, eps_dim)
dn_xz = Data_Network_xz(x, z, n_layers=n_layer_disc, n_hidden=n_hidden_disc)
dn_zz = Data_Network_zz(z,z)
dn_xx = Data_Network_xx(x,x)

# %% [markdown]
# ### Optimizers section:

# %%
"""qvars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "inference")
pvars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "generative")
dvars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "discriminator")
dvars_xx = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "discriminator_xx")
dvars_zz = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "discriminator_zz")

opt = tf.train.AdamOptimizer(1e-3, beta1=0.5)
train_gen_op =  opt.minimize(gen_loss, var_list=qvars + pvars)
train_disc_op = opt.minimize(disc_loss, var_list=dvars + dvars_xx)"""

# Train disc op does not contain dvars_zz?

disc_params = list(dn_zz.parameters())+list(dn_xz.parameters())+list(dn_xx.parameters())
disc_optimizer = torch.optim.Adam( disc_params, lr=1e-3)

gen_params = list(gen.parameters()) + list(inf.parameters())
gen_optimizer = torch.optim.Adam(gen_params, lr = 1e-3)

# %% [markdown]
# ### Learning procedure

# %%
p_x = gen(z)
q_z = inf(x)

decoder_logit = dn_xz(p_x,z)
encoder_logit = dn_xz(x,q_z)

bce = nn.BCELoss()
sigmoid = nn.Sigmoid()

#NB! Not sure if such xz loss description is correct

zeros = torch.zeros_like(decoder_logit)
decoder_loss = bce(sigmoid(decoder_logit),torch.zeros_like(decoder_logit))
encoder_loss = bce(sigmoid(encoder_logit),torch.ones_like(encoder_logit))

dis_loss_xz =torch.mean(encoder_loss+decoder_loss)

decoder_loss2 = bce(sigmoid(decoder_logit),torch.ones_like(decoder_logit))
encoder_loss2 = bce(sigmoid(encoder_logit),torch.zeros_like(encoder_logit))

gen_loss_xz = torch.mean((decoder_loss2)  + torch.mean(encoder_loss2))


"""
rec_z = inference_network(p_x, latent_dim, n_layer_inf, n_hidden_inf, eps_dim, reuse=True)
rec_x = generative_network(q_z, input_dim , n_layer_gen, n_hidden_gen,  eps_dim, reuse=True)
"""

rec_z = inf(p_x)
rec_x = gen(q_z)

"""
x_logit_real = data_network_xx(x, x)
x_logit_fake = data_network_xx(x, rec_x, reuse=True)
z_logit_real = data_network_zz(z, z)
z_logit_fake = data_network_zz(z, rec_z,  reuse=True)
""" 
x_logit_real = dn_xx(x,x)
x_logit_fake = dn_xx(x,rec_x)


z_logit_real = dn_zz(z,z)
z_logit_fake = dn_zz(z,rec_z)

"""
x_sigmoid_real = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_real, labels=tf.ones_like(x_logit_real))
x_sigmoid_fake = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_fake, labels=tf.zeros_like(x_logit_fake))
"""
x_sigmoid_real = bce(sigmoid(x_logit_real),torch.ones_like(x_logit_real))
x_sigmoid_fake = bce(sigmoid(x_logit_fake),torch.zeros_like(x_logit_fake))

x_sigmoid_real2 = bce(sigmoid(x_logit_real),torch.zeros_like(x_logit_real))
x_sigmoid_fake2 = bce(sigmoid(x_logit_fake),torch.ones_like(x_logit_fake))

"""x_sigmoid_real2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_real, labels=tf.zeros_like(x_logit_real))
x_sigmoid_fake2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_fake, labels=tf.ones_like(x_logit_fake))

z_sigmoid_real2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=z_logit_real, labels=tf.zeros_like(z_logit_real))
z_sigmoid_fake2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=z_logit_fake, labels=tf.ones_like(z_logit_fake))"""

z_sigmoid_real = bce(sigmoid(z_logit_real),torch.ones_like(z_logit_real))
z_sigmoid_fake = bce(sigmoid(z_logit_fake),torch.zeros_like(z_logit_fake))

z_sigmoid_real2 = bce(sigmoid(z_logit_real),torch.zeros_like(z_logit_real))
z_sigmoid_fake2 = bce(sigmoid(z_logit_fake),torch.ones_like(z_logit_fake))

"""
dis_loss_x = tf.reduce_mean(x_sigmoid_real + x_sigmoid_fake)
dis_loss_z = tf.reduce_mean(z_sigmoid_real + z_sigmoid_fake)
disc_loss = dis_loss_xz + dis_loss_x + dis_loss_z
"""
dis_loss_x = torch.mean(x_sigmoid_real + x_sigmoid_fake)
dis_loss_z = torch.mean(z_sigmoid_real + z_sigmoid_fake)
disc_loss = dis_loss_xz + dis_loss_x + dis_loss_z

cost_x = torch.mean(x_sigmoid_real2 + x_sigmoid_fake2) 
cost_z = torch.mean(z_sigmoid_real2 + z_sigmoid_fake2)


gen_loss = gen_loss_xz + cost_x  + cost_z

# %%
"""config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.1
sess = tf.Session(config=config)
sess.run(tf.global_variables_initializer())


FG = []
FD = []

for epoch in tqdm( range(n_epoch), total=n_epoch):
    X_dataset= shuffle(X_dataset)
    Z_dataset= shuffle(Z_dataset)
    i = 0
    for xmb, zmb in iter_data(X_dataset, Z_dataset, size=batch_size):
        i = i + 1
        for _ in range(1):
            f_d, _ = sess.run([disc_loss, train_disc_op], feed_dict={x: xmb, z:zmb})
        for _ in range(5):                                        #  ??? why 5
            f_g, _ = sess.run([[gen_loss, gen_loss_xz, cost_x], train_gen_op], feed_dict={x: xmb, z:zmb})

        FG.append(f_g)
        FD.append(f_d)

    print("epoch %d iter %d: discloss %f genloss %f adv_x %f recons_x %f " % (epoch, i, f_d, f_g[0], f_g[1], f_g[2]))

"""


for epoch in tqdm( range(n_epoch), total=n_epoch):
    X_dataset= shuffle(X_dataset)
    Z_dataset= shuffle(Z_dataset)
    
    bce = nn.BCELoss()
    sigmoid = nn.Sigmoid()

    FG = []
    FD = []
    i = 0
    f_g= [None]*3
    f_d = None
    
    for xmb, zmb in iter_data(X_dataset, Z_dataset, size=batch_size):
        
        x = torch.Tensor(xmb)
        z = torch.Tensor(zmb)
        i = i+1
        
        p_x = gen(z)
        q_z = inf(x)
        decoder_logit = dn_xz(p_x,z)
        encoder_logit = dn_xz(x,q_z)
    
        #NB! Not sure if such xz loss description is correct

      
        decoder_loss = bce(sigmoid(decoder_logit),torch.zeros_like(decoder_logit))
        encoder_loss = bce(sigmoid(encoder_logit),torch.ones_like(encoder_logit))
        
        dis_loss_xz =torch.mean(encoder_loss+decoder_loss)

        decoder_loss2 = bce(sigmoid(decoder_logit),torch.ones_like(decoder_logit))
        encoder_loss2 = bce(sigmoid(encoder_logit),torch.zeros_like(encoder_logit))

        gen_loss_xz = torch.mean((decoder_loss2)  + torch.mean(encoder_loss2))
        
        rec_z = inf(p_x)
        rec_x = gen(q_z)

        """
        x_logit_real = data_network_xx(x, x)
        x_logit_fake = data_network_xx(x, rec_x, reuse=True)
        z_logit_real = data_network_zz(z, z)
        z_logit_fake = data_network_zz(z, rec_z,  reuse=True)
        """ 
        x_logit_real = dn_xx(x,x)
        x_logit_fake = dn_xx(x,rec_x)
        z_logit_real = dn_zz(z,z)
        z_logit_fake = dn_zz(z,rec_z)

        """
        x_sigmoid_real = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_real, labels=tf.ones_like(x_logit_real))
        x_sigmoid_fake = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_fake, labels=tf.zeros_like(x_logit_fake))
        """
        x_sigmoid_real = bce(sigmoid(x_logit_real),torch.ones_like(x_logit_real))
        x_sigmoid_fake = bce(sigmoid(x_logit_fake),torch.zeros_like(x_logit_fake))

        x_sigmoid_real2 = bce(sigmoid(x_logit_real),torch.zeros_like(x_logit_real))
        x_sigmoid_fake2 = bce(sigmoid(x_logit_fake),torch.ones_like(x_logit_fake))

        """x_sigmoid_real2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_real, labels=tf.zeros_like(x_logit_real))
        x_sigmoid_fake2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit_fake, labels=tf.ones_like(x_logit_fake))

        z_sigmoid_real2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=z_logit_real, labels=tf.zeros_like(z_logit_real))
        z_sigmoid_fake2 = tf.nn.sigmoid_cross_entropy_with_logits(logits=z_logit_fake, labels=tf.ones_like(z_logit_fake))"""

        z_sigmoid_real = bce(sigmoid(z_logit_real),torch.ones_like(z_logit_real))
        z_sigmoid_fake = bce(sigmoid(z_logit_fake),torch.zeros_like(z_logit_fake))

        z_sigmoid_real2 = bce(sigmoid(z_logit_real),torch.zeros_like(z_logit_real))
        z_sigmoid_fake2 = bce(sigmoid(z_logit_fake),torch.ones_like(z_logit_fake))

        """
        dis_loss_x = tf.reduce_mean(x_sigmoid_real + x_sigmoid_fake)
        dis_loss_z = tf.reduce_mean(z_sigmoid_real + z_sigmoid_fake)
        disc_loss = dis_loss_xz + dis_loss_x + dis_loss_z
        """
        dis_loss_x = torch.mean(x_sigmoid_real + x_sigmoid_fake)
        dis_loss_z = torch.mean(z_sigmoid_real + z_sigmoid_fake)
        disc_loss = dis_loss_xz + dis_loss_x + dis_loss_z

        cost_x = torch.mean(x_sigmoid_real2 + x_sigmoid_fake2) 
        cost_z = torch.mean(z_sigmoid_real2 + z_sigmoid_fake2)
        gen_loss = gen_loss_xz + cost_x  + cost_z
        
        for _ in range(1):
            disc_optimizer.zero_grad()
            disc_loss.backward(retain_graph = True)
            disc_optimizer.step()
            f_d = disc_loss
            
        for _ in range(5):
            gen_optimizer.zero_grad()
            gen_loss.backward(retain_graph = True)
            gen_optimizer.step()
            
            gen_optimizer.zero_grad()
            gen_loss_xz.backward(retain_graph = True)
            gen_optimizer.step()

            gen_optimizer.zero_grad()
            cost_x.backward(retain_graph = True)
            gen_optimizer.step()

            
            f_g[0] = gen_loss
            f_g[1] = gen_loss_xz
            f_g[2] = cost_x
        
    
    FG.append(f_g)
    FD.append(f_d)
    
    print("epoch %d iter %d: discloss %f genloss %f adv_x %f recons_x %f " % (epoch, i, f_d, f_g[0], f_g[1], f_g[2]))
# Out:
#   0%|          | 1/300 [00:01<09:02,  1.81s/it]
# epoch 0 iter 2: discloss 5.243550 genloss 3.632247 adv_x 1.125541 recons_x 1.128735
#   1%|          | 2/300 [00:03<08:15,  1.66s/it]
# epoch 1 iter 2: discloss 10.265113 genloss 4.786588 adv_x 3.078215 recons_x 0.963498
#   1%|          | 3/300 [00:04<07:45,  1.57s/it]
# epoch 2 iter 2: discloss 10.912133 genloss 2.779107 adv_x 0.896785 recons_x 1.007600
#   1%|▏         | 4/300 [00:05<07:27,  1.51s/it]
# epoch 3 iter 2: discloss 38.883064 genloss 3.681925 adv_x 0.712770 recons_x 0.884535
#   2%|▏         | 5/300 [00:07<07:15,  1.48s/it]
# epoch 4 iter 2: discloss 3.914149 genloss 4.642971 adv_x 1.737804 recons_x 1.371424
#   2%|▏         | 6/300 [00:08<07:35,  1.55s/it]
# epoch 5 iter 2: discloss 8.877085 genloss 4.603600 adv_x 0.848235 recons_x 0.983536
#   2%|▏         | 7/300 [00:10<07:17,  1.49s/it]
# epoch 6 iter 2: discloss 6.361981 genloss 3.558336 adv_x 1.005410 recons_x 0.996510
#   3%|▎         | 8/300 [00:11<07:02,  1.45s/it]
# epoch 7 iter 2: discloss 5.541917 genloss 3.408161 adv_x 0.991546 recons_x 1.100822
#   3%|▎         | 9/300 [00:13<06:53,  1.42s/it]
# epoch 8 iter 2: discloss 8.299594 genloss 4.071492 adv_x 1.254675 recons_x 0.832782
#   3%|▎         | 10/300 [00:14<06:48,  1.41s/it]
# epoch 9 iter 2: discloss 4.520295 genloss 4.099412 adv_x 1.174893 recons_x 1.497026
#   4%|▎         | 11/300 [00:15<06:44,  1.40s/it]
# epoch 10 iter 2: discloss 4.303112 genloss 4.169353 adv_x 1.225099 recons_x 1.460120
#   4%|▍         | 12/300 [00:17<06:35,  1.37s/it]
# epoch 11 iter 2: discloss 4.487969 genloss 4.036480 adv_x 1.162088 recons_x 1.476945
#   4%|▍         | 13/300 [00:18<06:45,  1.41s/it]
# epoch 12 iter 2: discloss 4.253284 genloss 4.211375 adv_x 1.283200 recons_x 1.503514
#   5%|▍         | 14/300 [00:19<06:39,  1.40s/it]
# epoch 13 iter 2: discloss 4.114320 genloss 4.362189 adv_x 1.422431 recons_x 1.485767
#   5%|▌         | 15/300 [00:21<06:47,  1.43s/it]
# epoch 14 iter 2: discloss 4.209309 genloss 4.292928 adv_x 1.350110 recons_x 1.503140
#   5%|▌         | 16/300 [00:22<06:40,  1.41s/it]
# epoch 15 iter 2: discloss 4.287645 genloss 4.229283 adv_x 1.294528 recons_x 1.500661
#   6%|▌         | 17/300 [00:24<06:33,  1.39s/it]
# epoch 16 iter 2: discloss 4.195692 genloss 5.646162 adv_x 1.152762 recons_x 2.520084
#   6%|▌         | 18/300 [00:25<06:28,  1.38s/it]
# epoch 17 iter 2: discloss 4.225200 genloss 4.296130 adv_x 1.346908 recons_x 1.524807
#   6%|▋         | 19/300 [00:26<06:24,  1.37s/it]
# epoch 18 iter 2: discloss 4.229807 genloss 5.227683 adv_x 1.108269 recons_x 2.191634
#   7%|▋         | 20/300 [00:28<06:24,  1.37s/it]
# epoch 19 iter 2: discloss 4.068197 genloss 4.459847 adv_x 1.441951 recons_x 1.556016
#   7%|▋         | 21/300 [00:29<06:37,  1.42s/it]
# epoch 20 iter 2: discloss 4.141491 genloss 4.358440 adv_x 1.373364 recons_x 1.557037
#   7%|▋         | 22/300 [00:31<06:35,  1.42s/it]
# epoch 21 iter 2: discloss 4.116561 genloss 4.382007 adv_x 1.383404 recons_x 1.564623
#   8%|▊         | 23/300 [00:32<06:35,  1.43s/it]
# epoch 22 iter 2: discloss 4.097742 genloss 4.379821 adv_x 1.407275 recons_x 1.537719
#   8%|▊         | 24/300 [00:34<06:42,  1.46s/it]
# epoch 23 iter 2: discloss 3.640165 genloss 6.712926 adv_x 1.426875 recons_x 3.676158
#   8%|▊         | 25/300 [00:35<06:45,  1.47s/it]
# epoch 24 iter 2: discloss 4.094970 genloss 4.493524 adv_x 1.336250 recons_x 1.702127
#   9%|▊         | 26/300 [00:37<06:59,  1.53s/it]
# epoch 25 iter 2: discloss 3.825691 genloss 4.746951 adv_x 1.512124 recons_x 1.749881
#   9%|▉         | 27/300 [00:38<07:04,  1.55s/it]
# epoch 26 iter 2: discloss 3.912859 genloss 4.579865 adv_x 1.474087 recons_x 1.630364
#   9%|▉         | 28/300 [00:40<07:23,  1.63s/it]
# epoch 27 iter 2: discloss 3.994160 genloss 4.626215 adv_x 1.370929 recons_x 1.771090
#  10%|▉         | 29/300 [00:42<07:26,  1.65s/it]
# epoch 28 iter 2: discloss 3.837987 genloss 4.652494 adv_x 1.508484 recons_x 1.655740
#  10%|█         | 30/300 [00:44<07:33,  1.68s/it]
# epoch 29 iter 2: discloss 3.819052 genloss 4.670737 adv_x 1.504354 recons_x 1.669334
#  10%|█         | 31/300 [00:46<07:48,  1.74s/it]
# epoch 30 iter 2: discloss 3.863311 genloss 4.644668 adv_x 1.458594 recons_x 1.675146
#  11%|█         | 32/300 [00:47<07:58,  1.79s/it]
# epoch 31 iter 2: discloss 3.661022 genloss 4.871718 adv_x 1.616246 recons_x 1.732715
#  11%|█         | 33/300 [00:50<08:26,  1.90s/it]
# epoch 32 iter 2: discloss 3.684048 genloss 4.814009 adv_x 1.585814 recons_x 1.707457
#  11%|█▏        | 34/300 [00:52<08:34,  1.93s/it]
# epoch 33 iter 2: discloss 3.708965 genloss 4.764526 adv_x 1.533976 recons_x 1.712742
#  12%|█▏        | 35/300 [00:54<08:36,  1.95s/it]
# epoch 34 iter 2: discloss 3.653918 genloss 5.026736 adv_x 1.535735 recons_x 1.907334
#  12%|█▏        | 36/300 [00:56<08:51,  2.01s/it]
# epoch 35 iter 2: discloss 3.648309 genloss 4.849454 adv_x 1.563802 recons_x 1.752273
#  12%|█▏        | 37/300 [00:58<09:03,  2.07s/it]
# epoch 36 iter 2: discloss 3.732652 genloss 4.774529 adv_x 1.487902 recons_x 1.762156
#  13%|█▎        | 38/300 [01:00<08:55,  2.04s/it]
# epoch 37 iter 2: discloss 3.807650 genloss 4.674829 adv_x 1.599171 recons_x 1.596343
#  13%|█▎        | 39/300 [01:02<08:35,  1.97s/it]
# epoch 38 iter 2: discloss 3.590342 genloss 4.910336 adv_x 1.628049 recons_x 1.714780
#  13%|█▎        | 40/300 [01:04<08:21,  1.93s/it]
# epoch 39 iter 2: discloss 3.697612 genloss 4.853179 adv_x 1.647691 recons_x 1.652030
#  14%|█▎        | 41/300 [01:06<08:16,  1.92s/it]
# epoch 40 iter 2: discloss 3.698928 genloss 4.856732 adv_x 1.581093 recons_x 1.714590
#  14%|█▍        | 42/300 [01:07<08:08,  1.89s/it]
# epoch 41 iter 2: discloss 4.235469 genloss 4.649116 adv_x 1.277451 recons_x 1.831303
#  14%|█▍        | 43/300 [01:09<08:24,  1.96s/it]
# epoch 42 iter 2: discloss 4.063122 genloss 5.851275 adv_x 1.069174 recons_x 2.710773
#  15%|█▍        | 44/300 [01:11<08:12,  1.92s/it]
# epoch 43 iter 2: discloss 3.710999 genloss 4.879154 adv_x 1.400304 recons_x 1.801956
#  15%|█▌        | 45/300 [01:13<08:09,  1.92s/it]
# epoch 44 iter 2: discloss 3.429794 genloss 6.513082 adv_x 1.364609 recons_x 3.408676
#  15%|█▌        | 46/300 [01:15<08:08,  1.92s/it]
# epoch 45 iter 2: discloss 3.738607 genloss 4.923694 adv_x 1.329322 recons_x 1.929885
#  16%|█▌        | 47/300 [01:17<07:55,  1.88s/it]
# epoch 46 iter 2: discloss 3.857893 genloss 19.375500 adv_x 1.106500 recons_x 16.641886
#  16%|█▌        | 48/300 [01:19<07:58,  1.90s/it]
# epoch 47 iter 2: discloss 2.868431 genloss 18.529064 adv_x 1.411761 recons_x 11.298248
#  16%|█▋        | 49/300 [01:21<07:51,  1.88s/it]
# epoch 48 iter 2: discloss 3.328191 genloss 5.525952 adv_x 1.488416 recons_x 2.228330
#  17%|█▋        | 50/300 [01:23<07:48,  1.87s/it]
# epoch 49 iter 2: discloss 3.392830 genloss 5.200081 adv_x 1.488200 recons_x 1.991599
#  17%|█▋        | 51/300 [01:24<07:46,  1.87s/it]
# epoch 50 iter 2: discloss 3.664485 genloss 5.007307 adv_x 1.246732 recons_x 2.046044
#  17%|█▋        | 52/300 [01:26<07:41,  1.86s/it]
# epoch 51 iter 2: discloss 3.690308 genloss 5.040765 adv_x 1.191472 recons_x 2.080170
#  18%|█▊        | 53/300 [01:28<07:37,  1.85s/it]
# epoch 52 iter 2: discloss 3.786851 genloss 5.003006 adv_x 1.122336 recons_x 2.130216
#  18%|█▊        | 54/300 [01:30<07:43,  1.88s/it]
# epoch 53 iter 2: discloss 3.601332 genloss 5.038169 adv_x 1.289057 recons_x 2.039834
#  18%|█▊        | 55/300 [01:32<07:44,  1.89s/it]
# epoch 54 iter 2: discloss 3.422248 genloss 5.244369 adv_x 1.389617 recons_x 2.078412
#  19%|█▊        | 56/300 [01:34<07:49,  1.92s/it]
# epoch 55 iter 2: discloss 3.451767 genloss 5.235504 adv_x 1.381107 recons_x 2.079199
#  19%|█▉        | 57/300 [01:36<07:51,  1.94s/it]
# epoch 56 iter 2: discloss 3.422238 genloss 5.438043 adv_x 1.354139 recons_x 2.275687
#  19%|█▉        | 58/300 [01:38<07:47,  1.93s/it]
# epoch 57 iter 2: discloss 3.397947 genloss 5.289181 adv_x 1.413671 recons_x 2.049487
#  20%|█▉        | 59/300 [01:40<08:04,  2.01s/it]
# epoch 58 iter 2: discloss 2.845102 genloss 11.841600 adv_x 1.411275 recons_x 4.551455
#  20%|██        | 60/300 [01:42<08:29,  2.12s/it]
# epoch 59 iter 2: discloss 3.185941 genloss 5.736822 adv_x 1.398165 recons_x 2.419593
#  20%|██        | 61/300 [01:44<08:18,  2.08s/it]
# epoch 60 iter 2: discloss 3.213207 genloss 5.951701 adv_x 1.360350 recons_x 2.567911
#  21%|██        | 62/300 [01:47<08:14,  2.08s/it]
# epoch 61 iter 2: discloss 3.149509 genloss 5.725589 adv_x 1.415740 recons_x 2.308266
#  21%|██        | 63/300 [01:48<07:54,  2.00s/it]
# epoch 62 iter 2: discloss 3.125643 genloss 5.716108 adv_x 1.409541 recons_x 2.270816
#  21%|██▏       | 64/300 [01:50<07:37,  1.94s/it]
# epoch 63 iter 2: discloss 3.360616 genloss 5.753627 adv_x 1.356453 recons_x 2.360021
#  22%|██▏       | 65/300 [01:52<07:22,  1.88s/it]
# epoch 64 iter 2: discloss 3.010687 genloss 6.385988 adv_x 1.363058 recons_x 2.829750
#  22%|██▏       | 66/300 [01:54<07:29,  1.92s/it]
# epoch 65 iter 2: discloss 3.081269 genloss 5.753755 adv_x 1.449516 recons_x 2.251122
#  22%|██▏       | 67/300 [01:56<07:36,  1.96s/it]
# epoch 66 iter 2: discloss 3.127215 genloss 5.648582 adv_x 1.469801 recons_x 2.196704
#  23%|██▎       | 68/300 [01:58<07:31,  1.95s/it]
# epoch 67 iter 2: discloss 3.475819 genloss 5.284886 adv_x 1.378547 recons_x 2.027797
#  23%|██▎       | 69/300 [02:00<07:23,  1.92s/it]
# epoch 68 iter 2: discloss 3.539727 genloss 5.141610 adv_x 1.411340 recons_x 1.911784
#  23%|██▎       | 70/300 [02:02<07:18,  1.91s/it]
# epoch 69 iter 2: discloss 3.698689 genloss 4.944375 adv_x 1.414373 recons_x 1.793617
#  24%|██▎       | 71/300 [02:03<07:11,  1.88s/it]
# epoch 70 iter 2: discloss 3.169407 genloss 5.752634 adv_x 1.428921 recons_x 2.399522
#  24%|██▍       | 72/300 [02:05<07:05,  1.87s/it]
# epoch 71 iter 2: discloss 3.369682 genloss 5.453543 adv_x 1.426783 recons_x 2.136750
#  24%|██▍       | 73/300 [02:07<07:03,  1.86s/it]
# epoch 72 iter 2: discloss 3.306716 genloss 5.565575 adv_x 1.452786 recons_x 2.273272
#  25%|██▍       | 74/300 [02:09<07:00,  1.86s/it]
# epoch 73 iter 2: discloss 3.195528 genloss 5.640174 adv_x 1.512505 recons_x 2.159972
#  25%|██▌       | 75/300 [02:11<07:05,  1.89s/it]
# epoch 74 iter 2: discloss 3.407478 genloss 5.299015 adv_x 1.535406 recons_x 1.985569
#  25%|██▌       | 76/300 [02:13<07:48,  2.09s/it]
# epoch 75 iter 2: discloss 3.076256 genloss 6.584595 adv_x 1.335314 recons_x 2.940750
#  26%|██▌       | 77/300 [02:16<08:05,  2.18s/it]
# epoch 76 iter 2: discloss 3.164997 genloss 5.658582 adv_x 1.606355 recons_x 2.112646
#  26%|██▌       | 78/300 [02:18<07:58,  2.16s/it]
# epoch 77 iter 2: discloss 3.325881 genloss 5.469044 adv_x 1.543571 recons_x 2.040239
#  26%|██▋       | 79/300 [02:20<07:39,  2.08s/it]
# epoch 78 iter 2: discloss 3.596121 genloss 5.063533 adv_x 1.522002 recons_x 1.799924
#  27%|██▋       | 80/300 [02:22<07:26,  2.03s/it]
# epoch 79 iter 2: discloss 3.499067 genloss 5.231353 adv_x 1.532830 recons_x 1.903225
#  27%|██▋       | 81/300 [02:24<07:14,  1.99s/it]
# epoch 80 iter 2: discloss 3.668602 genloss 5.094983 adv_x 1.407356 recons_x 1.813119
#  27%|██▋       | 82/300 [02:26<07:20,  2.02s/it]
# epoch 81 iter 2: discloss 3.701111 genloss 4.949255 adv_x 1.491706 recons_x 1.766086
#  28%|██▊       | 83/300 [02:28<07:11,  1.99s/it]
# epoch 82 iter 2: discloss 3.759990 genloss 4.906729 adv_x 1.435416 recons_x 1.732685
#  28%|██▊       | 84/300 [02:30<07:05,  1.97s/it]
# epoch 83 iter 2: discloss 3.595897 genloss 4.934910 adv_x 1.481637 recons_x 1.684381
#  28%|██▊       | 85/300 [02:32<07:13,  2.02s/it]
# epoch 84 iter 2: discloss 3.387253 genloss 5.330527 adv_x 1.411072 recons_x 1.897712
#  29%|██▊       | 86/300 [02:34<07:04,  1.99s/it]
# epoch 85 iter 2: discloss 3.524158 genloss 5.060039 adv_x 1.470320 recons_x 1.659974
#  29%|██▉       | 87/300 [02:36<07:07,  2.01s/it]
# epoch 86 iter 2: discloss 2.971626 genloss 6.171907 adv_x 1.591857 recons_x 2.127257
#  29%|██▉       | 88/300 [02:38<07:11,  2.03s/it]
# epoch 87 iter 2: discloss 3.405701 genloss 5.302838 adv_x 1.420077 recons_x 1.904836
#  30%|██▉       | 89/300 [02:40<07:18,  2.08s/it]
# epoch 88 iter 2: discloss 3.316613 genloss 5.409071 adv_x 1.547426 recons_x 1.815112
#  30%|███       | 90/300 [02:42<07:23,  2.11s/it]
# epoch 89 iter 2: discloss 3.397155 genloss 5.418140 adv_x 1.359610 recons_x 1.958946
#  30%|███       | 91/300 [02:44<07:18,  2.10s/it]
# epoch 90 iter 2: discloss 3.422828 genloss 5.131423 adv_x 1.563075 recons_x 1.729792
#  31%|███       | 92/300 [02:46<07:08,  2.06s/it]
# epoch 91 iter 2: discloss 3.484163 genloss 5.127640 adv_x 1.399400 recons_x 1.866483
#  31%|███       | 93/300 [02:48<07:13,  2.09s/it]
# epoch 92 iter 2: discloss 3.555919 genloss 4.945253 adv_x 1.515227 recons_x 1.677060
#  31%|███▏      | 94/300 [02:51<07:25,  2.16s/it]
# epoch 93 iter 2: discloss 3.637065 genloss 4.861386 adv_x 1.496919 recons_x 1.563479
#  32%|███▏      | 95/300 [02:53<07:07,  2.09s/it]
# epoch 94 iter 2: discloss 3.642247 genloss 4.890026 adv_x 1.483176 recons_x 1.560183
#  32%|███▏      | 96/300 [02:55<07:09,  2.10s/it]
# epoch 95 iter 2: discloss 3.550982 genloss 4.969098 adv_x 1.457248 recons_x 1.640824
#  32%|███▏      | 97/300 [02:57<06:53,  2.03s/it]
# epoch 96 iter 2: discloss 3.691103 genloss 4.795012 adv_x 1.431584 recons_x 1.558577
#  33%|███▎      | 98/300 [02:59<06:43,  2.00s/it]
# epoch 97 iter 2: discloss 3.727902 genloss 4.763644 adv_x 1.443885 recons_x 1.501366
#  33%|███▎      | 99/300 [03:01<06:44,  2.01s/it]
# epoch 98 iter 2: discloss 3.650533 genloss 4.827049 adv_x 1.487799 recons_x 1.539752
#  33%|███▎      | 100/300 [03:03<07:00,  2.10s/it]
# epoch 99 iter 2: discloss 3.505335 genloss 5.139433 adv_x 1.402773 recons_x 1.796412
#  34%|███▎      | 101/300 [03:05<07:04,  2.13s/it]
# epoch 100 iter 2: discloss 3.293016 genloss 5.494820 adv_x 1.502645 recons_x 1.891085
#  34%|███▍      | 102/300 [03:07<07:17,  2.21s/it]
# epoch 101 iter 2: discloss 3.248870 genloss 5.678442 adv_x 1.485198 recons_x 1.720916
#  34%|███▍      | 103/300 [03:10<07:19,  2.23s/it]
# epoch 102 iter 2: discloss 3.361197 genloss 5.557611 adv_x 1.408098 recons_x 1.974531
#  35%|███▍      | 104/300 [03:12<07:14,  2.22s/it]
# epoch 103 iter 2: discloss 3.396327 genloss 5.284457 adv_x 1.546479 recons_x 1.649835
#  35%|███▌      | 105/300 [03:14<07:07,  2.19s/it]
# epoch 104 iter 2: discloss 3.496523 genloss 5.211790 adv_x 1.452506 recons_x 1.581335
#  35%|███▌      | 106/300 [03:16<07:10,  2.22s/it]
# epoch 105 iter 2: discloss 3.488817 genloss 5.156839 adv_x 1.447381 recons_x 1.653166
#  36%|███▌      | 107/300 [03:19<07:25,  2.31s/it]
# epoch 106 iter 2: discloss 3.396173 genloss 5.291926 adv_x 1.469126 recons_x 1.635767
#  36%|███▌      | 108/300 [03:21<07:14,  2.26s/it]
# epoch 107 iter 2: discloss 3.422810 genloss 5.143925 adv_x 1.518343 recons_x 1.666004
#  36%|███▋      | 109/300 [03:23<06:59,  2.20s/it]
# epoch 108 iter 2: discloss 3.441680 genloss 5.190841 adv_x 1.487059 recons_x 1.681058
#  37%|███▋      | 110/300 [03:25<07:00,  2.21s/it]
# epoch 109 iter 2: discloss 3.468781 genloss 5.150217 adv_x 1.509459 recons_x 1.615955
#  37%|███▋      | 111/300 [03:27<06:54,  2.19s/it]
# epoch 110 iter 2: discloss 3.514205 genloss 5.090612 adv_x 1.506741 recons_x 1.620747
#  37%|███▋      | 112/300 [03:30<06:47,  2.17s/it]
# epoch 111 iter 2: discloss 3.458791 genloss 5.192359 adv_x 1.539777 recons_x 1.595537
#  38%|███▊      | 113/300 [03:32<06:52,  2.21s/it]
# epoch 112 iter 2: discloss 3.471739 genloss 5.147250 adv_x 1.485994 recons_x 1.665538
#  38%|███▊      | 114/300 [03:34<06:54,  2.23s/it]
# epoch 113 iter 2: discloss 3.493439 genloss 5.087547 adv_x 1.555346 recons_x 1.578546
#  38%|███▊      | 115/300 [03:36<06:41,  2.17s/it]
# epoch 114 iter 2: discloss 3.563778 genloss 5.059391 adv_x 1.547990 recons_x 1.539833
#  39%|███▊      | 116/300 [03:38<06:28,  2.11s/it]
# epoch 115 iter 2: discloss 3.379920 genloss 5.361797 adv_x 1.533247 recons_x 1.664614
#  39%|███▉      | 117/300 [03:40<06:25,  2.10s/it]
# epoch 116 iter 2: discloss 3.263182 genloss 5.578297 adv_x 1.575179 recons_x 1.651733
#  39%|███▉      | 118/300 [03:42<06:16,  2.07s/it]
# epoch 117 iter 2: discloss 2.998269 genloss 6.231852 adv_x 1.567614 recons_x 2.018785
#  40%|███▉      | 119/300 [03:44<06:06,  2.03s/it]
# epoch 118 iter 2: discloss 3.165846 genloss 5.988589 adv_x 1.589544 recons_x 1.767512
#  40%|████      | 120/300 [03:46<05:55,  1.98s/it]
# epoch 119 iter 2: discloss 3.192330 genloss 5.700801 adv_x 1.654985 recons_x 1.644332
#  40%|████      | 121/300 [03:48<05:50,  1.96s/it]
# epoch 120 iter 2: discloss 3.304439 genloss 5.647402 adv_x 1.569474 recons_x 1.631106
#  41%|████      | 122/300 [03:50<05:44,  1.94s/it]
# epoch 121 iter 2: discloss 3.142909 genloss 5.788778 adv_x 1.657005 recons_x 1.747137
#  41%|████      | 123/300 [03:52<05:47,  1.97s/it]
# epoch 122 iter 2: discloss 3.158286 genloss 6.099457 adv_x 1.601484 recons_x 2.028869
#  41%|████▏     | 124/300 [03:54<05:42,  1.95s/it]
# epoch 123 iter 2: discloss 3.192045 genloss 5.791574 adv_x 1.691607 recons_x 1.718037
#  42%|████▏     | 125/300 [03:56<05:36,  1.92s/it]
# epoch 124 iter 2: discloss 3.295605 genloss 5.662172 adv_x 1.523352 recons_x 1.734043
#  42%|████▏     | 126/300 [03:58<05:33,  1.92s/it]
# epoch 125 iter 2: discloss 3.389262 genloss 5.461791 adv_x 1.568563 recons_x 1.556182
#  42%|████▏     | 127/300 [04:00<05:47,  2.01s/it]
# epoch 126 iter 2: discloss 3.345776 genloss 5.557027 adv_x 1.508225 recons_x 1.617652
#  43%|████▎     | 128/300 [04:02<06:01,  2.10s/it]
# epoch 127 iter 2: discloss 3.395087 genloss 5.555394 adv_x 1.531002 recons_x 1.534838
#  43%|████▎     | 129/300 [04:04<05:58,  2.10s/it]
# epoch 128 iter 2: discloss 3.279276 genloss 5.626905 adv_x 1.550747 recons_x 1.640834
#  43%|████▎     | 130/300 [04:06<05:53,  2.08s/it]
# epoch 129 iter 2: discloss 3.275604 genloss 5.761876 adv_x 1.547560 recons_x 1.642517
#  44%|████▎     | 131/300 [04:09<06:03,  2.15s/it]
# epoch 130 iter 2: discloss 3.277520 genloss 5.590977 adv_x 1.632008 recons_x 1.687773
#  44%|████▍     | 132/300 [04:11<06:10,  2.21s/it]
# epoch 131 iter 2: discloss 3.312716 genloss 5.621837 adv_x 1.605787 recons_x 1.774481
#  44%|████▍     | 133/300 [04:13<05:52,  2.11s/it]
# epoch 132 iter 2: discloss 3.166238 genloss 5.942156 adv_x 1.621835 recons_x 1.696143
#  45%|████▍     | 134/300 [04:15<06:00,  2.17s/it]
# epoch 133 iter 2: discloss 3.138115 genloss 5.819327 adv_x 1.730863 recons_x 1.754185
#  45%|████▌     | 135/300 [04:17<06:06,  2.22s/it]
# epoch 134 iter 2: discloss 3.014713 genloss 6.326833 adv_x 1.549481 recons_x 2.004147
#  45%|████▌     | 136/300 [04:20<06:04,  2.22s/it]
# epoch 135 iter 2: discloss 2.956190 genloss 6.198499 adv_x 1.757323 recons_x 1.920463
#  46%|████▌     | 137/300 [04:22<06:11,  2.28s/it]
# epoch 136 iter 2: discloss 3.143293 genloss 6.022379 adv_x 1.576955 recons_x 1.815869
#  46%|████▌     | 138/300 [04:24<06:10,  2.29s/it]
# epoch 137 iter 2: discloss 3.071831 genloss 5.991981 adv_x 1.706964 recons_x 1.753693
#  46%|████▋     | 139/300 [04:27<06:11,  2.31s/it]
# epoch 138 iter 2: discloss 3.397435 genloss 5.448720 adv_x 1.641521 recons_x 1.494343
#  47%|████▋     | 140/300 [04:29<06:09,  2.31s/it]
# epoch 139 iter 2: discloss 3.189050 genloss 5.952520 adv_x 1.761056 recons_x 1.608154
#  47%|████▋     | 141/300 [04:31<05:55,  2.23s/it]
# epoch 140 iter 2: discloss 3.014343 genloss 6.026822 adv_x 1.819963 recons_x 1.798176
#  47%|████▋     | 142/300 [04:33<05:42,  2.17s/it]
# epoch 141 iter 2: discloss 3.073318 genloss 6.394520 adv_x 1.631748 recons_x 1.781361
#  48%|████▊     | 143/300 [04:35<05:29,  2.10s/it]
# epoch 142 iter 2: discloss 3.210164 genloss 5.842855 adv_x 1.693783 recons_x 1.604658
#  48%|████▊     | 144/300 [04:37<05:18,  2.04s/it]
# epoch 143 iter 2: discloss 2.920107 genloss 6.641132 adv_x 1.717275 recons_x 1.846254
#  48%|████▊     | 145/300 [04:39<05:10,  2.00s/it]
# epoch 144 iter 2: discloss 3.136634 genloss 6.121144 adv_x 1.663737 recons_x 1.673391
#  49%|████▊     | 146/300 [04:41<05:03,  1.97s/it]
# epoch 145 iter 2: discloss 2.942677 genloss 6.513256 adv_x 1.784895 recons_x 1.770895
#  49%|████▉     | 147/300 [04:43<05:05,  1.99s/it]
# epoch 146 iter 2: discloss 3.047669 genloss 6.409349 adv_x 1.801254 recons_x 1.616885
#  49%|████▉     | 148/300 [04:45<05:04,  2.00s/it]
# epoch 147 iter 2: discloss 3.158553 genloss 6.185864 adv_x 1.851709 recons_x 1.533766
#  50%|████▉     | 149/300 [04:47<04:57,  1.97s/it]
# epoch 148 iter 2: discloss 2.977521 genloss 6.566399 adv_x 1.765982 recons_x 1.747686
#  50%|█████     | 150/300 [04:49<05:00,  2.00s/it]
# epoch 149 iter 2: discloss 2.849630 genloss 6.873545 adv_x 1.915697 recons_x 1.853549
#  50%|█████     | 151/300 [04:51<05:01,  2.02s/it]
# epoch 150 iter 2: discloss 2.769796 genloss 7.116511 adv_x 1.844217 recons_x 1.959495
#  51%|█████     | 152/300 [04:53<05:06,  2.07s/it]
# epoch 151 iter 2: discloss 2.978866 genloss 6.760834 adv_x 1.705808 recons_x 1.795274
#  51%|█████     | 153/300 [04:55<05:15,  2.14s/it]
# epoch 152 iter 2: discloss 2.924809 genloss 6.524245 adv_x 1.760705 recons_x 1.728051
#  51%|█████▏    | 154/300 [04:57<05:00,  2.06s/it]
# epoch 153 iter 2: discloss 3.129097 genloss 6.341537 adv_x 1.644799 recons_x 1.663075
#  52%|█████▏    | 155/300 [04:59<04:49,  2.00s/it]
# epoch 154 iter 2: discloss 3.163957 genloss 6.877577 adv_x 1.503559 recons_x 2.050025
#  52%|█████▏    | 156/300 [05:01<04:43,  1.97s/it]
# epoch 155 iter 2: discloss 2.822733 genloss 7.000417 adv_x 1.924811 recons_x 1.862213
#  52%|█████▏    | 157/300 [05:03<04:36,  1.93s/it]
# epoch 156 iter 2: discloss 2.886509 genloss 6.743975 adv_x 1.681122 recons_x 2.049212
#  53%|█████▎    | 158/300 [05:05<04:29,  1.90s/it]
# epoch 157 iter 2: discloss 2.954601 genloss 6.534676 adv_x 1.863977 recons_x 1.672300
#  53%|█████▎    | 159/300 [05:07<04:39,  1.98s/it]
# epoch 158 iter 2: discloss 2.891374 genloss 6.825378 adv_x 1.770190 recons_x 1.788203
#  53%|█████▎    | 160/300 [05:09<04:46,  2.05s/it]
# epoch 159 iter 2: discloss 2.940751 genloss 7.097530 adv_x 1.729065 recons_x 1.961781
#  54%|█████▎    | 161/300 [05:11<04:36,  1.99s/it]
# epoch 160 iter 2: discloss 2.746729 genloss 6.743584 adv_x 1.980746 recons_x 1.932887
#  54%|█████▍    | 162/300 [05:13<04:30,  1.96s/it]
# epoch 161 iter 2: discloss 2.840326 genloss 7.365412 adv_x 1.631709 recons_x 2.196856
#  54%|█████▍    | 163/300 [05:15<04:25,  1.94s/it]
# epoch 162 iter 2: discloss 2.736965 genloss 7.333894 adv_x 2.014732 recons_x 1.941062
#  55%|█████▍    | 164/300 [05:17<04:20,  1.91s/it]
# epoch 163 iter 2: discloss 2.567950 genloss 9.991728 adv_x 2.001627 recons_x 2.371394
#  55%|█████▌    | 165/300 [05:18<04:21,  1.93s/it]
# epoch 164 iter 2: discloss 2.489150 genloss 8.191441 adv_x 2.009580 recons_x 2.294935
#  55%|█████▌    | 166/300 [05:20<04:21,  1.95s/it]
# epoch 165 iter 2: discloss 2.476581 genloss 7.748668 adv_x 2.089988 recons_x 2.007549
#  56%|█████▌    | 167/300 [05:22<04:21,  1.97s/it]
# epoch 166 iter 2: discloss 2.649539 genloss 8.052288 adv_x 1.724742 recons_x 2.283209
#  56%|█████▌    | 168/300 [05:25<04:22,  1.99s/it]
# epoch 167 iter 2: discloss 2.669972 genloss 7.177703 adv_x 2.077472 recons_x 1.840831
#  56%|█████▋    | 169/300 [05:26<04:17,  1.96s/it]
# epoch 168 iter 2: discloss 2.894500 genloss 7.046629 adv_x 1.842395 recons_x 1.724395
#  57%|█████▋    | 170/300 [05:28<04:16,  1.97s/it]
# epoch 169 iter 2: discloss 2.638804 genloss 7.567446 adv_x 2.011793 recons_x 1.893267
#  57%|█████▋    | 171/300 [05:31<04:28,  2.08s/it]
# epoch 170 iter 2: discloss 2.981129 genloss 6.706816 adv_x 2.012371 recons_x 1.630431
#  57%|█████▋    | 172/300 [05:33<04:51,  2.27s/it]
# epoch 171 iter 2: discloss 3.003510 genloss 6.599056 adv_x 1.893883 recons_x 1.715454
#  58%|█████▊    | 173/300 [05:35<04:37,  2.18s/it]
# epoch 172 iter 2: discloss 2.799932 genloss 7.414348 adv_x 1.876796 recons_x 1.893664
#  58%|█████▊    | 174/300 [05:38<04:39,  2.22s/it]
# epoch 173 iter 2: discloss 2.688252 genloss 7.889369 adv_x 1.933790 recons_x 2.165601
#  58%|█████▊    | 175/300 [05:41<05:04,  2.44s/it]
# epoch 174 iter 2: discloss 2.721437 genloss 7.905958 adv_x 1.835850 recons_x 2.005326
#  59%|█████▊    | 176/300 [05:43<05:06,  2.47s/it]
# epoch 175 iter 2: discloss 2.558969 genloss 7.580448 adv_x 2.173201 recons_x 2.066012
#  59%|█████▉    | 177/300 [05:46<05:07,  2.50s/it]
# epoch 176 iter 2: discloss 2.676124 genloss 7.841308 adv_x 1.998163 recons_x 2.120991
#  59%|█████▉    | 178/300 [05:48<04:48,  2.37s/it]
# epoch 177 iter 2: discloss 2.674565 genloss 7.815159 adv_x 2.126798 recons_x 2.025000
#  60%|█████▉    | 179/300 [05:50<04:38,  2.30s/it]
# epoch 178 iter 2: discloss 2.530307 genloss 7.936925 adv_x 2.060451 recons_x 2.089957
#  60%|██████    | 180/300 [05:53<04:46,  2.39s/it]
# epoch 179 iter 2: discloss 2.819680 genloss 7.164454 adv_x 2.068347 recons_x 1.820221
#  60%|██████    | 181/300 [05:55<04:36,  2.32s/it]
# epoch 180 iter 2: discloss 2.928668 genloss 7.035399 adv_x 1.929251 recons_x 1.680219
#  61%|██████    | 182/300 [05:57<04:25,  2.25s/it]
# epoch 181 iter 2: discloss 2.417155 genloss 9.103506 adv_x 2.097761 recons_x 2.651776
#  61%|██████    | 183/300 [05:59<04:16,  2.19s/it]
# epoch 182 iter 2: discloss 2.664436 genloss 10.394760 adv_x 2.411367 recons_x 3.133517
#  61%|██████▏   | 184/300 [06:01<04:27,  2.31s/it]
# epoch 183 iter 2: discloss 4.582271 genloss 47.881737 adv_x 5.251457 recons_x 17.005672
#  62%|██████▏   | 185/300 [06:04<04:35,  2.39s/it]
# epoch 184 iter 2: discloss 1.728202 genloss 48.990822 adv_x 5.860498 recons_x 21.955349
#  62%|██████▏   | 186/300 [06:06<04:29,  2.36s/it]
# epoch 185 iter 2: discloss 2.239457 genloss 21.589123 adv_x 1.928404 recons_x 9.764259
#  62%|██████▏   | 187/300 [06:08<04:16,  2.27s/it]
# epoch 186 iter 2: discloss 0.670133 genloss 96.011902 adv_x 13.253795 recons_x 30.980761
#  63%|██████▎   | 188/300 [06:10<04:05,  2.19s/it]
# epoch 187 iter 2: discloss 10.738865 genloss 72.470680 adv_x 3.587268 recons_x 39.263062
#  63%|██████▎   | 189/300 [06:12<03:53,  2.11s/it]
# epoch 188 iter 2: discloss 1.629468 genloss 81.312378 adv_x 4.935160 recons_x 46.619347
#  63%|██████▎   | 190/300 [06:14<03:50,  2.09s/it]
# epoch 189 iter 2: discloss 1.786820 genloss 66.704819 adv_x 7.828613 recons_x 28.978281
#  64%|██████▎   | 191/300 [06:16<03:41,  2.03s/it]
# epoch 190 iter 2: discloss 1.295023 genloss 67.627151 adv_x 8.523996 recons_x 29.047464
#  64%|██████▍   | 192/300 [06:19<03:47,  2.11s/it]
# epoch 191 iter 2: discloss 1.769058 genloss 77.299049 adv_x 2.767159 recons_x 22.997068
#  64%|██████▍   | 193/300 [06:21<03:45,  2.11s/it]
# epoch 192 iter 2: discloss 3.264206 genloss 81.781281 adv_x 1.176761 recons_x 27.510532
#  65%|██████▍   | 194/300 [06:23<03:37,  2.06s/it]
# epoch 193 iter 2: discloss 0.514861 genloss 70.553101 adv_x 10.796313 recons_x 29.259064
#  65%|██████▌   | 195/300 [06:25<03:34,  2.04s/it]
# epoch 194 iter 2: discloss 1.261798 genloss 70.481979 adv_x 8.165062 recons_x 28.300270
#  65%|██████▌   | 196/300 [06:27<03:36,  2.08s/it]
# epoch 195 iter 2: discloss 0.257196 genloss 77.055130 adv_x 16.847610 recons_x 29.404938
#  66%|██████▌   | 197/300 [06:29<03:36,  2.11s/it]
# epoch 196 iter 2: discloss 0.269298 genloss 81.624969 adv_x 11.500803 recons_x 39.227978
#  66%|██████▌   | 198/300 [06:31<03:34,  2.11s/it]
# epoch 197 iter 2: discloss 2.424970 genloss 106.612656 adv_x 4.928885 recons_x 55.102100
#  66%|██████▋   | 199/300 [06:33<03:31,  2.09s/it]
# epoch 198 iter 2: discloss 0.214149 genloss 81.725876 adv_x 20.083342 recons_x 30.463457
#  67%|██████▋   | 200/300 [06:35<03:28,  2.08s/it]
# epoch 199 iter 2: discloss 0.705654 genloss 76.873344 adv_x 14.632478 recons_x 30.485344
#  67%|██████▋   | 201/300 [06:37<03:31,  2.14s/it]
# epoch 200 iter 2: discloss 0.666674 genloss 77.738670 adv_x 18.415495 recons_x 29.793873
#  67%|██████▋   | 202/300 [06:40<03:29,  2.14s/it]
# epoch 201 iter 2: discloss 0.857678 genloss 49.958313 adv_x 13.991596 recons_x 17.174341
#  68%|██████▊   | 203/300 [06:42<03:22,  2.09s/it]
# epoch 202 iter 2: discloss 0.476777 genloss 79.709396 adv_x 11.425506 recons_x 36.667618
#  68%|██████▊   | 204/300 [06:44<03:28,  2.17s/it]
# epoch 203 iter 2: discloss 0.661578 genloss 80.080116 adv_x 13.336180 recons_x 35.239872
#  68%|██████▊   | 205/300 [06:46<03:27,  2.18s/it]
# epoch 204 iter 2: discloss 0.139002 genloss 87.770538 adv_x 25.723467 recons_x 30.087826
#  69%|██████▊   | 206/300 [06:48<03:21,  2.14s/it]
# epoch 205 iter 2: discloss 0.196584 genloss 90.708374 adv_x 28.702461 recons_x 30.163284
#  69%|██████▉   | 207/300 [06:50<03:13,  2.08s/it]
# epoch 206 iter 2: discloss 0.337356 genloss 82.354828 adv_x 20.187744 recons_x 30.258076
#  69%|██████▉   | 208/300 [06:52<03:09,  2.06s/it]
# epoch 207 iter 2: discloss 0.479478 genloss 74.732491 adv_x 11.211221 recons_x 36.227497
#  70%|██████▉   | 209/300 [06:54<03:05,  2.03s/it]
# epoch 208 iter 2: discloss 0.193086 genloss 93.463005 adv_x 31.028336 recons_x 30.426437
#  70%|███████   | 210/300 [06:56<03:02,  2.03s/it]
# epoch 209 iter 2: discloss 0.130945 genloss 98.108047 adv_x 32.404114 recons_x 30.504700
#  70%|███████   | 211/300 [06:58<02:59,  2.01s/it]
# epoch 210 iter 2: discloss 0.233579 genloss 95.035072 adv_x 29.996014 recons_x 32.860573
#  71%|███████   | 212/300 [07:00<02:55,  2.00s/it]
# epoch 211 iter 2: discloss 0.301987 genloss 105.278641 adv_x 29.671518 recons_x 40.764439
#  71%|███████   | 213/300 [07:02<03:02,  2.10s/it]
# epoch 212 iter 2: discloss 0.200067 genloss 104.167557 adv_x 30.187099 recons_x 30.787708
#  71%|███████▏  | 214/300 [07:05<03:06,  2.17s/it]
# epoch 213 iter 2: discloss 0.062890 genloss 103.839081 adv_x 40.692554 recons_x 30.881065
#  72%|███████▏  | 215/300 [07:07<03:01,  2.13s/it]
# epoch 214 iter 2: discloss 0.059493 genloss 90.634125 adv_x 35.419800 recons_x 22.883343
#  72%|███████▏  | 216/300 [07:09<02:57,  2.11s/it]
# epoch 215 iter 2: discloss 0.055169 genloss 117.239731 adv_x 53.564163 recons_x 31.040457
#  72%|███████▏  | 217/300 [07:11<03:04,  2.23s/it]
# epoch 216 iter 2: discloss 0.171771 genloss 104.299454 adv_x 37.713722 recons_x 31.137131
#  73%|███████▎  | 218/300 [07:13<03:00,  2.20s/it]
# epoch 217 iter 2: discloss 2.070159 genloss 93.299118 adv_x 33.096069 recons_x 27.197845
#  73%|███████▎  | 219/300 [07:16<02:54,  2.15s/it]
# epoch 218 iter 2: discloss 0.054794 genloss 98.909172 adv_x 34.740761 recons_x 31.263742
#  73%|███████▎  | 220/300 [07:18<03:01,  2.26s/it]
# epoch 219 iter 2: discloss 0.316459 genloss 95.634552 adv_x 26.973946 recons_x 31.598915
#  74%|███████▎  | 221/300 [07:20<02:59,  2.27s/it]
# epoch 220 iter 2: discloss 0.064448 genloss 98.207191 adv_x 33.832958 recons_x 31.397253
#  74%|███████▍  | 222/300 [07:22<02:49,  2.17s/it]
# epoch 221 iter 2: discloss 0.140820 genloss 98.072227 adv_x 33.733639 recons_x 31.616131
#  74%|███████▍  | 223/300 [07:24<02:45,  2.15s/it]
# epoch 222 iter 2: discloss 0.279261 genloss 107.431244 adv_x 31.159067 recons_x 43.047173
#  75%|███████▍  | 224/300 [07:26<02:37,  2.07s/it]
# epoch 223 iter 2: discloss 0.310677 genloss 105.810104 adv_x 29.713484 recons_x 43.269699
#  75%|███████▌  | 225/300 [07:28<02:30,  2.01s/it]
# epoch 224 iter 2: discloss 0.346134 genloss 93.984383 adv_x 29.639954 recons_x 31.582537
#  75%|███████▌  | 226/300 [07:30<02:26,  1.98s/it]
# epoch 225 iter 2: discloss 0.291903 genloss 94.167770 adv_x 29.796801 recons_x 31.601234
#  76%|███████▌  | 227/300 [07:32<02:28,  2.03s/it]
# epoch 226 iter 2: discloss 0.258574 genloss 94.439926 adv_x 29.975132 recons_x 31.653065
#  76%|███████▌  | 228/300 [07:34<02:25,  2.02s/it]
# epoch 227 iter 2: discloss 0.208171 genloss 94.832298 adv_x 30.291559 recons_x 31.708248
#  76%|███████▋  | 229/300 [07:36<02:26,  2.06s/it]
# epoch 228 iter 2: discloss 0.169253 genloss 99.490311 adv_x 30.611080 recons_x 31.731297
#  77%|███████▋  | 230/300 [07:39<02:27,  2.11s/it]
# epoch 229 iter 2: discloss 0.035221 genloss 98.198677 adv_x 33.493546 recons_x 31.774776
#  77%|███████▋  | 231/300 [07:41<02:27,  2.13s/it]
# epoch 230 iter 2: discloss 0.098896 genloss 95.080711 adv_x 30.875191 recons_x 31.835716
#  77%|███████▋  | 232/300 [07:43<02:21,  2.08s/it]
# epoch 231 iter 2: discloss 0.088582 genloss 97.027512 adv_x 31.518627 recons_x 31.890949
#  78%|███████▊  | 233/300 [07:45<02:23,  2.14s/it]
# epoch 232 iter 2: discloss 0.100777 genloss 103.797348 adv_x 31.836828 recons_x 31.926392
#  78%|███████▊  | 234/300 [07:47<02:16,  2.07s/it]
# epoch 233 iter 2: discloss 0.025182 genloss 104.068848 adv_x 39.080288 recons_x 31.970913
#  78%|███████▊  | 235/300 [07:49<02:13,  2.05s/it]
# epoch 234 iter 2: discloss 0.033872 genloss 98.757210 adv_x 33.548897 recons_x 31.984531
#  79%|███████▊  | 236/300 [07:51<02:12,  2.08s/it]
# epoch 235 iter 2: discloss 0.024103 genloss 118.290787 adv_x 36.217190 recons_x 32.037529
#  79%|███████▉  | 237/300 [07:53<02:06,  2.01s/it]
# epoch 236 iter 2: discloss 0.023492 genloss 100.208778 adv_x 34.962299 recons_x 32.110104
#  79%|███████▉  | 238/300 [07:55<02:03,  1.99s/it]
# epoch 237 iter 2: discloss 0.032323 genloss 98.372551 adv_x 33.074509 recons_x 32.130814
#  80%|███████▉  | 239/300 [07:57<01:59,  1.97s/it]
# epoch 238 iter 2: discloss 0.034182 genloss 98.430389 adv_x 33.105801 recons_x 32.172287
#  80%|████████  | 240/300 [07:59<02:00,  2.01s/it]
# epoch 239 iter 2: discloss 0.031871 genloss 98.599426 adv_x 33.229233 recons_x 32.202911
#  80%|████████  | 241/300 [08:01<02:04,  2.11s/it]
# epoch 240 iter 2: discloss 0.028407 genloss 98.947525 adv_x 33.343739 recons_x 32.219116
#  81%|████████  | 242/300 [08:04<02:08,  2.22s/it]
# epoch 241 iter 2: discloss 0.025161 genloss 105.497574 adv_x 33.504475 recons_x 32.267475
#  81%|████████  | 243/300 [08:06<02:12,  2.33s/it]
# epoch 242 iter 2: discloss 0.028390 genloss 102.046234 adv_x 34.205616 recons_x 32.301128
#  81%|████████▏ | 244/300 [08:09<02:17,  2.45s/it]
# epoch 243 iter 2: discloss 0.018186 genloss 103.152214 adv_x 37.516296 recons_x 32.363876
#  82%|████████▏ | 245/300 [08:11<02:09,  2.36s/it]
# epoch 244 iter 2: discloss 0.019928 genloss 105.644470 adv_x 38.945351 recons_x 32.366192
#  82%|████████▏ | 246/300 [08:13<02:03,  2.28s/it]
# epoch 245 iter 2: discloss 0.018918 genloss 104.526962 adv_x 38.792305 recons_x 32.415909
#  82%|████████▏ | 247/300 [08:15<02:00,  2.27s/it]
# epoch 246 iter 2: discloss 0.019059 genloss 107.776489 adv_x 35.341766 recons_x 32.469921
#  83%|████████▎ | 248/300 [08:18<02:01,  2.34s/it]
# epoch 247 iter 2: discloss 0.018466 genloss 100.443069 adv_x 34.616722 recons_x 32.513916
#  83%|████████▎ | 249/300 [08:20<02:01,  2.38s/it]
# epoch 248 iter 2: discloss 0.016733 genloss 104.419601 adv_x 38.566490 recons_x 32.467617
#  83%|████████▎ | 250/300 [08:23<01:55,  2.31s/it]
# epoch 249 iter 2: discloss 0.017494 genloss 103.613022 adv_x 34.541656 recons_x 32.531498
#  84%|████████▎ | 251/300 [08:25<01:56,  2.39s/it]
# epoch 250 iter 2: discloss 0.015098 genloss 113.346657 adv_x 47.380764 recons_x 32.581203
#  84%|████████▍ | 252/300 [08:28<01:54,  2.39s/it]
# epoch 251 iter 2: discloss 0.021631 genloss 113.512741 adv_x 47.280167 recons_x 32.598785
#  84%|████████▍ | 253/300 [08:30<01:52,  2.39s/it]
# epoch 252 iter 2: discloss 0.025163 genloss 108.442917 adv_x 38.844398 recons_x 32.611206
#  85%|████████▍ | 254/300 [08:32<01:46,  2.30s/it]
# epoch 253 iter 2: discloss 0.015747 genloss 101.086060 adv_x 34.872284 recons_x 32.624950
#  85%|████████▌ | 255/300 [08:35<01:45,  2.35s/it]
# epoch 254 iter 2: discloss 0.021682 genloss 99.333466 adv_x 32.884018 recons_x 32.689030
#  85%|████████▌ | 256/300 [08:37<01:43,  2.35s/it]
# epoch 255 iter 2: discloss 0.051688 genloss 97.785660 adv_x 29.501043 recons_x 33.434563
#  86%|████████▌ | 257/300 [08:39<01:42,  2.39s/it]
# epoch 256 iter 2: discloss 0.024503 genloss 102.692368 adv_x 36.423790 recons_x 32.783337
#  86%|████████▌ | 258/300 [08:41<01:36,  2.30s/it]
# epoch 257 iter 2: discloss 0.657061 genloss 68.255905 adv_x 28.239998 recons_x 6.478889
#  86%|████████▋ | 259/300 [08:44<01:34,  2.30s/it]
# epoch 258 iter 2: discloss 0.615805 genloss 67.272896 adv_x 27.219328 recons_x 6.455061
#  87%|████████▋ | 260/300 [08:46<01:35,  2.39s/it]
# epoch 259 iter 2: discloss 0.341904 genloss 74.323639 adv_x 28.519327 recons_x 11.913515
#  87%|████████▋ | 261/300 [08:49<01:32,  2.37s/it]
# epoch 260 iter 2: discloss 0.200192 genloss 84.584229 adv_x 29.827070 recons_x 20.559227
#  87%|████████▋ | 262/300 [08:51<01:26,  2.26s/it]
# epoch 261 iter 2: discloss 0.712284 genloss 65.644318 adv_x 25.722321 recons_x 6.339602
#  88%|████████▊ | 263/300 [08:53<01:24,  2.29s/it]
# epoch 262 iter 2: discloss 0.249712 genloss 65.830528 adv_x 25.746723 recons_x 6.448308
#  88%|████████▊ | 264/300 [08:55<01:21,  2.26s/it]
# epoch 263 iter 2: discloss 0.309309 genloss 66.417221 adv_x 26.301786 recons_x 6.465364
#  88%|████████▊ | 265/300 [08:57<01:17,  2.23s/it]
# epoch 264 iter 2: discloss 0.343862 genloss 66.496620 adv_x 25.716080 recons_x 6.466795
#  89%|████████▊ | 266/300 [09:00<01:16,  2.26s/it]
# epoch 265 iter 2: discloss 0.073743 genloss 117.942001 adv_x 49.222412 recons_x 34.988739
#  89%|████████▉ | 267/300 [09:02<01:15,  2.28s/it]
# epoch 266 iter 2: discloss 0.190937 genloss 72.136902 adv_x 31.786451 recons_x 6.590490
#  89%|████████▉ | 268/300 [09:04<01:11,  2.23s/it]
# epoch 267 iter 2: discloss 0.195770 genloss 72.188782 adv_x 31.893339 recons_x 6.602678
#  90%|████████▉ | 269/300 [09:06<01:06,  2.15s/it]
# epoch 268 iter 2: discloss 0.191265 genloss 72.396828 adv_x 31.913074 recons_x 6.699336
#  90%|█████████ | 270/300 [09:08<01:02,  2.08s/it]
# epoch 269 iter 2: discloss 0.179450 genloss 72.585190 adv_x 32.033932 recons_x 6.773482
#  90%|█████████ | 271/300 [09:10<01:00,  2.09s/it]
# epoch 270 iter 2: discloss 0.148019 genloss 72.842850 adv_x 32.172985 recons_x 6.875922
#  91%|█████████ | 272/300 [09:12<00:58,  2.07s/it]
# epoch 271 iter 2: discloss 0.141600 genloss 72.998726 adv_x 32.358963 recons_x 6.853867
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-ba8f687ffbba> in <module>
#     123             gen_optimizer.zero_grad()
#     124             gen_loss.backward(retain_graph = True)
# --> 125             gen_optimizer.step()
#     126
#     127             gen_optimizer.zero_grad()
#
# ~/anaconda3/envs/marsanomalies/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#     105                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     106
# --> 107                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     108
#     109         return loss
#
# KeyboardInterrupt:

# %%
datasetX_test = four_five_gaussians(p1=0)
save_path_x = result_dir + 'X_4gmm_data_test.png'

# %%
# create X dataset

X_np_data_test = datasetX_test.data['samples']
X_targets_test = datasetX_test.data['label']

# %%
X_np_outliers = np.random.uniform(low=X_np_data_test.min(), high=X_np_data_test.max(), size=(N_NOISY,2))#outlier testing size 20\n"
X_outliers_target = [15]* X_np_outliers.shape[0]
X_np_data_test = np.concatenate([X_np_data_test, X_np_outliers], axis=0)
X_targets_test = np.concatenate([X_targets_test, X_outliers_target], axis=0)

# %%
idx_inliers = X_targets_test <4 
idx_outliers = np.logical_not(idx_inliers)

# %% [markdown]
# Plotting final (cleaned) test dataset

# %%
plt.clf()
fig_mx, ax = plt.subplots(nrows=1, ncols=1, figsize=(4.5, 4.5))
ax.scatter(X_np_data_test[idx_inliers, 0], X_np_data_test[idx_inliers, 1], c=cm.tab20(X_targets_test[idx_inliers].astype(float)/15.0),
           edgecolor='none', alpha=0.5, label="Normal samples")

ax.scatter(X_np_data_test[idx_outliers, 0], X_np_data_test[idx_outliers, 1], c=cm.tab20(X_targets_test[idx_outliers].astype(float)/15),
       edgecolor='none', alpha=0.5, label="Anomalous samples", marker='x')

ax.set_xlabel('$x_1$'); ax.set_ylabel('$x_2$')
ax.axis('on')
ax.set_title("Test dataset")
ax.legend()
plt.savefig(save_path_x, transparent=True, bbox_inches='tight')
plt.show()

# %%
# create Z dataset

datasetZ_test = sample_GMM(X_np_data_test.shape[0], means_z, variances_z, priors_z, sources=('features', ))
save_path = result_dir + 'Z_gmm_data_test.png'
# plot_GMM(dataset, save_path)

Z_np_data_test = datasetZ_test.data['samples']
Z_targets_test = datasetZ_test.data['label']

fig_mx, ax = plt.subplots(nrows=1, ncols=1, figsize=(4.5, 4.5))
ax.scatter(Z_np_data_test[:, 0], Z_np_data_test[:, 1],
           edgecolor='none', alpha=0.5)
ax.set_xlim(-3, 3); ax.set_ylim(-3.5, 3.5)
ax.set_xlabel('$z_1$'); ax.set_ylabel('$z_2$')
ax.axis('on')
plt.savefig(save_path, transparent=True, bbox_inches='tight')
plt.show()

# %%
### Testing

# %%
x = torch.Tensor(X_np_data_test) 
z = torch.Tensor(Z_np_data_test)

imz = gen(z)
imx = inf(x)
rmz = gen(imz)
rmx = inf(im)
score_dz = sess.run(mahalanobis_dis_z, feed_dict=feed_dict)
score_dxx = sess.run(x_sigmoid_real + x_sigmoid_fake, feed_dict=feed_dict)

score = score_dz #+ score_dxx
score = np.linalg.norm(imz, ord=2, axis=1, keepdims=False)
print(score)
def zmar(imz):
    return np.linalg.norm(imz, ord=2, axis=1, keepdims=False)
